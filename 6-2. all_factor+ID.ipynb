# %% [markdown]
# 將IDW計算出的台灣空汙擴散圖整合成鄉鎮週暴露量（含ID欄位）

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import os

# %%
# 測項清單
factors = ["NO", "NO2", "NOx", "O3", "PM10", "PM25", "SO2"]

# === 1️⃣ 載入鄉鎮邊界（名稱欄位） ===
gml_path = "TOWN_MOI_1131028.gml"
taiwan_map = gpd.read_file(gml_path)
taiwan_map = taiwan_map.set_crs("EPSG:3824").to_crs("EPSG:4326")
taiwan_map = taiwan_map.rename(columns={"名稱": "town"})

# === 2️⃣ 載入鄉鎮對應ID ===
id_map = pd.read_csv("ID_CNAME.csv", dtype=str)
id_map = id_map.rename(columns={"ID1_CITY": "ID", "C_NAME": "town"})

# === 3️⃣ 建立 120x120 格點 ===
iInterval = (122.7 - 119) / 120
jInterval = (25.5 - 21.8) / 120
grid_points = [Point(119 + i * iInterval, 25.5 - j * jInterval) for j in range(120) for i in range(120)]
grid_gdf = gpd.GeoDataFrame(geometry=grid_points, crs="EPSG:4326")

# === 4️⃣ 儲存所有結果（主鍵為 town, year, week） ===
all_results = {}

# %%
# === 5️⃣ 處理每個測項 ===
for factor in factors:
    input_folder = f"./5_grid_output/{factor}"
    if not os.path.exists(input_folder):
        print(f"❌ 資料夾不存在: {input_folder}")
        continue

    for year in range(2015, 2020):
        for week in range(1, 52):
            grid_path = os.path.join(input_folder, f"{factor}_{year}_week_{week}.csv")
            if not os.path.exists(grid_path):
                continue

            try:
                grid_values = pd.read_csv(grid_path, skiprows=1, header=None).values.flatten()
            except Exception as e:
                print(f"❌ 無法讀取 {grid_path}: {e}")
                continue

            if len(grid_values) != len(grid_gdf):
                print(f"⚠️ 長度不符：{grid_path} ({len(grid_values)} vs {len(grid_gdf)})")
                continue

            valid_mask = grid_values != -1
            if valid_mask.sum() == 0:
                print(f"⚠️ 全為 -1：{grid_path}")
                continue

            grid_subset = grid_gdf[valid_mask].copy()
            grid_subset["value"] = grid_values[valid_mask]

            # 空間連接：格點 → 鄉鎮
            joined = gpd.sjoin(grid_subset, taiwan_map[["geometry", "town"]], predicate='within', how='inner')

            # 計算每個鄉鎮覆蓋比例（格點數法）
            grouped = joined.groupby('town')

            for town, group in grouped:
                # 該鄉鎮的總格點數（所有格點落在該鄉鎮內）
                total_grid_in_town = len(grid_gdf[grid_gdf.within(taiwan_map.loc[taiwan_map["town"] == town, "geometry"].values[0])])

                # 有值的格點數
                valid_grid_in_town = len(group)

                coverage_ratio = valid_grid_in_town / total_grid_in_town

                # 若覆蓋不到一半 → 略過
                if coverage_ratio < 0.5:
                    print(f"⚠️{year} {week} {town} 覆蓋不足（{coverage_ratio:.2%}），略過。")
                    continue

                print(f"✅{year} {week}  {town} 覆蓋充足（{coverage_ratio:.2%}），計算。")

                # 計算週暴露量（7天平均）
                avg_val = round(group["value"].mean(), 2)
                key = (town, year, week)
                if key not in all_results:
                    all_results[key] = {}
                all_results[key][factor] = avg_val

            print(f"✅ 完成：{factor} {year} week {week}")
# Out:
# ✅2015 1  南投縣中寮鄉 覆蓋充足（97.70%），計算。
# ⚠️2015 1 南投縣仁愛鄉 覆蓋不足（5.76%），略過。
# ⚠️2015 1 南投縣信義鄉 覆蓋不足（1.65%），略過。
# ✅2015 1  南投縣南投市 覆蓋充足（114.11%），計算。
# ✅2015 1  南投縣名間鄉 覆蓋充足（118.21%），計算。
# ✅2015 1  南投縣國姓鄉 覆蓋充足（68.26%），計算。
# ✅2015 1  南投縣埔里鎮 覆蓋充足（95.67%），計算。
# ✅2015 1  南投縣水里鄉 覆蓋充足（62.89%），計算。
# ✅2015 1  南投縣竹山鎮 覆蓋充足（63.42%），計算。
# ✅2015 1  南投縣草屯鎮 覆蓋充足（90.14%），計算。
# ✅2015 1  南投縣集集鎮 覆蓋充足（88.45%），計算。
# ✅2015 1  南投縣魚池鄉 覆蓋充足（65.93%），計算。
# ✅2015 1  南投縣鹿谷鄉 覆蓋充足（81.95%），計算。
# ✅2015 1  嘉義市東區 覆蓋充足（78.49%），計算。
# ✅2015 1  嘉義市西區 覆蓋充足（156.84%），計算。
# ✅2015 1  嘉義縣中埔鄉 覆蓋充足（90.00%），計算。
# ✅2015 1  嘉義縣六腳鄉 覆蓋充足（112.78%），計算。
# ✅2015 1  嘉義縣大埔鄉 覆蓋充足（100.81%），計算。
# ✅2015 1  嘉義縣大林鎮 覆蓋充足（108.78%），計算。
# ✅2015 1  嘉義縣太保市 覆蓋充足（123.39%），計算。
# ✅2015 1  嘉義縣布袋鎮 覆蓋充足（88.91%），計算。
# ✅2015 1  嘉義縣新港鄉 覆蓋充足（106.18%），計算。
# ✅2015 1  嘉義縣朴子市 覆蓋充足（93.78%），計算。
# ✅2015 1  嘉義縣東石鄉 覆蓋充足（100.02%），計算。
# ✅2015 1  嘉義縣梅山鄉 覆蓋充足（58.82%），計算。
# ✅2015 1  嘉義縣民雄鄉 覆蓋充足（96.59%），計算。
# ✅2015 1  嘉義縣水上鄉 覆蓋充足（83.60%），計算。
# ✅2015 1  嘉義縣溪口鄉 覆蓋充足（144.53%），計算。
# ✅2015 1  嘉義縣番路鄉 覆蓋充足（83.37%），計算。
# ✅2015 1  嘉義縣竹崎鄉 覆蓋充足（59.75%），計算。
# ✅2015 1  嘉義縣義竹鄉 覆蓋充足（133.76%），計算。
# ✅2015 1  嘉義縣鹿草鄉 覆蓋充足（128.87%），計算。
# ✅2015 1  基隆市七堵區 覆蓋充足（125.04%），計算。
# ✅2015 1  基隆市仁愛區 覆蓋充足（257.15%），計算。
# ✅2015 1  基隆市信義區 覆蓋充足（110.51%），計算。
# ✅2015 1  基隆市安樂區 覆蓋充足（126.24%），計算。
# ✅2015 1  基隆市暖暖區 覆蓋充足（102.34%），計算。
# ✅2015 1  宜蘭縣三星鄉 覆蓋充足（119.74%），計算。
# ✅2015 1  宜蘭縣五結鄉 覆蓋充足（116.30%），計算。
# ✅2015 1  宜蘭縣冬山鄉 覆蓋充足（124.73%），計算。
# ⚠️2015 1 宜蘭縣南澳鄉 覆蓋不足（37.81%），略過。
# ✅2015 1  宜蘭縣員山鄉 覆蓋充足（82.76%），計算。
# ✅2015 1  宜蘭縣壯圍鄉 覆蓋充足（89.08%），計算。
# ⚠️2015 1 宜蘭縣大同鄉 覆蓋不足（19.78%），略過。
# ✅2015 1  宜蘭縣宜蘭市 覆蓋充足（153.97%），計算。
# ✅2015 1  宜蘭縣礁溪鄉 覆蓋充足（93.07%），計算。
# ✅2015 1  宜蘭縣蘇澳鎮 覆蓋充足（130.78%），計算。
# ✅2015 1  宜蘭縣頭城鎮 覆蓋充足（80.00%），計算。
# ✅2015 1  屏東縣三地門鄉 覆蓋充足（81.91%），計算。
# ✅2015 1  屏東縣九如鄉 覆蓋充足（108.69%），計算。
# ✅2015 1  屏東縣佳冬鄉 覆蓋充足（108.71%），計算。
# ✅2015 1  屏東縣來義鄉 覆蓋充足（57.75%），計算。
# ✅2015 1  屏東縣內埔鄉 覆蓋充足（121.47%），計算。
# ✅2015 1  屏東縣南州鄉 覆蓋充足（62.32%），計算。
# ✅2015 1  屏東縣屏東市 覆蓋充足（124.15%），計算。
# ✅2015 1  屏東縣崁頂鄉 覆蓋充足（138.82%），計算。
# ✅2015 1  屏東縣恆春鎮 覆蓋充足（99.71%），計算。
# ✅2015 1  屏東縣新園鄉 覆蓋充足（77.39%），計算。
# ✅2015 1  屏東縣新埤鄉 覆蓋充足（144.47%），計算。
# ✅2015 1  屏東縣春日鄉 覆蓋充足（82.84%），計算。
# ✅2015 1  屏東縣東港鎮 覆蓋充足（114.01%），計算。
# ✅2015 1  屏東縣枋寮鄉 覆蓋充足（96.78%），計算。
# ✅2015 1  屏東縣枋山鄉 覆蓋充足（259.16%），計算。
# ✅2015 1  屏東縣林邊鄉 覆蓋充足（137.18%），計算。
# ⚠️2015 1 屏東縣泰武鄉 覆蓋不足（47.19%），略過。
# ✅2015 1  屏東縣滿州鄉 覆蓋充足（117.85%），計算。
# ✅2015 1  屏東縣潮州鎮 覆蓋充足（82.63%），計算。
# ✅2015 1  屏東縣牡丹鄉 覆蓋充足（107.42%），計算。
# ✅2015 1  屏東縣獅子鄉 覆蓋充足（85.98%），計算。
# ✅2015 1  屏東縣琉球鄉 覆蓋充足（170.86%），計算。
# ✅2015 1  屏東縣瑪家鄉 覆蓋充足（94.96%），計算。
# ✅2015 1  屏東縣竹田鄉 覆蓋充足（118.56%），計算。
# ✅2015 1  屏東縣萬丹鄉 覆蓋充足（118.56%），計算。
# ✅2015 1  屏東縣萬巒鄉 覆蓋充足（57.76%），計算。
# ✅2015 1  屏東縣車城鄉 覆蓋充足（117.82%），計算。
# ✅2015 1  屏東縣里港鄉 覆蓋充足（100.82%），計算。
# ✅2015 1  屏東縣長治鄉 覆蓋充足（51.16%），計算。
# ⚠️2015 1 屏東縣霧臺鄉 覆蓋不足（3.84%），略過。
# ✅2015 1  屏東縣高樹鄉 覆蓋充足（87.02%），計算。
# ✅2015 1  屏東縣鹽埔鄉 覆蓋充足（118.79%），計算。
# ✅2015 1  屏東縣麟洛鄉 覆蓋充足（168.51%），計算。
# ✅2015 1  彰化縣二林鎮 覆蓋充足（101.64%），計算。
# ✅2015 1  彰化縣二水鄉 覆蓋充足（131.73%），計算。
# ✅2015 1  彰化縣伸港鄉 覆蓋充足（99.57%），計算。
# ✅2015 1  彰化縣北斗鎮 覆蓋充足（118.61%），計算。
# ✅2015 1  彰化縣和美鎮 覆蓋充足（122.71%），計算。
# ✅2015 1  彰化縣員林市 覆蓋充足（59.44%），計算。
# ✅2015 1  彰化縣埔心鄉 覆蓋充足（55.82%），計算。
# ✅2015 1  彰化縣埔鹽鄉 覆蓋充足（119.96%），計算。
# ✅2015 1  彰化縣埤頭鄉 覆蓋充足（137.86%），計算。
# ✅2015 1  彰化縣大城鄉 覆蓋充足（110.56%），計算。
# ✅2015 1  彰化縣大村鄉 覆蓋充足（153.86%），計算。
# ✅2015 1  彰化縣彰化市 覆蓋充足（71.25%），計算。
# ✅2015 1  彰化縣永靖鄉 覆蓋充足（115.44%），計算。
# ✅2015 1  彰化縣溪州鄉 覆蓋充足（118.39%），計算。
# ✅2015 1  彰化縣溪湖鎮 覆蓋充足（150.99%），計算。
# ✅2015 1  彰化縣田中鎮 覆蓋充足（68.00%），計算。
# ✅2015 1  彰化縣田尾鄉 覆蓋充足（94.82%），計算。
# ✅2015 1  彰化縣社頭鄉 覆蓋充足（130.46%），計算。
# ✅2015 1  彰化縣福興鄉 覆蓋充足（161.04%），計算。
# ✅2015 1  彰化縣秀水鄉 覆蓋充足（80.55%），計算。
# ✅2015 1  彰化縣竹塘鄉 覆蓋充足（111.85%），計算。
# ✅2015 1  彰化縣線西鄉 覆蓋充足（113.73%），計算。
# ✅2015 1  彰化縣芬園鄉 覆蓋充足（152.98%），計算。
# ✅2015 1  彰化縣花壇鄉 覆蓋充足（130.30%），計算。
# ✅2015 1  彰化縣芳苑鄉 覆蓋充足（104.76%），計算。
# ✅2015 1  彰化縣鹿港鎮 覆蓋充足（84.69%），計算。
# ✅2015 1  新北市三峽區 覆蓋充足（86.50%），計算。
# ✅2015 1  新北市三芝區 覆蓋充足（86.75%），計算。
# ✅2015 1  新北市三重區 覆蓋充足（65.14%），計算。
# ✅2015 1  新北市中和區 覆蓋充足（120.58%），計算。
# ✅2015 1  新北市五股區 覆蓋充足（102.37%），計算。
# ✅2015 1  新北市八里區 覆蓋充足（117.87%），計算。
# ✅2015 1  新北市土城區 覆蓋充足（117.38%），計算。
# ✅2015 1  新北市坪林區 覆蓋充足（69.61%），計算。
# ✅2015 1  新北市平溪區 覆蓋充足（131.69%），計算。
# ✅2015 1  新北市新店區 覆蓋充足（96.68%），計算。
# ✅2015 1  新北市新莊區 覆蓋充足（169.91%），計算。
# ✅2015 1  新北市板橋區 覆蓋充足（110.09%），計算。
# ✅2015 1  新北市林口區 覆蓋充足（129.46%），計算。
# ✅2015 1  新北市樹林區 覆蓋充足（110.11%），計算。
# ✅2015 1  新北市永和區 覆蓋充足（190.21%），計算。
# ✅2015 1  新北市汐止區 覆蓋充足（114.21%），計算。
# ✅2015 1  新北市淡水區 覆蓋充足（96.16%），計算。
# ✅2015 1  新北市深坑區 覆蓋充足（111.86%），計算。
# ⚠️2015 1 新北市烏來區 覆蓋不足（31.61%），略過。
# ✅2015 1  新北市瑞芳區 覆蓋充足（97.31%），計算。
# ✅2015 1  新北市石碇區 覆蓋充足（107.30%），計算。
# ✅2015 1  新北市石門區 覆蓋充足（110.52%），計算。
# ✅2015 1  新北市萬里區 覆蓋充足（110.56%），計算。
# ✅2015 1  新北市蘆洲區 覆蓋充足（151.81%），計算。
# ✅2015 1  新北市貢寮區 覆蓋充足（115.08%），計算。
# ✅2015 1  新北市金山區 覆蓋充足（98.16%），計算。
# ✅2015 1  新北市雙溪區 覆蓋充足（104.53%），計算。
# ✅2015 1  新北市鶯歌區 覆蓋充足（107.27%），計算。
# ✅2015 1  新竹市北區 覆蓋充足（99.36%），計算。
# ✅2015 1  新竹市東區 覆蓋充足（68.33%），計算。
# ✅2015 1  新竹市香山區 覆蓋充足（87.97%），計算。
# ⚠️2015 1 新竹縣五峰鄉 覆蓋不足（22.31%），略過。
# ✅2015 1  新竹縣北埔鄉 覆蓋充足（87.72%），計算。
# ✅2015 1  新竹縣寶山鄉 覆蓋充足（109.37%），計算。
# ⚠️2015 1 新竹縣尖石鄉 覆蓋不足（11.20%），略過。
# ✅2015 1  新竹縣峨眉鄉 覆蓋充足（125.87%），計算。
# ✅2015 1  新竹縣新埔鎮 覆蓋充足（97.34%），計算。
# ✅2015 1  新竹縣新豐鄉 覆蓋充足（117.40%），計算。
# ✅2015 1  新竹縣橫山鄉 覆蓋充足（107.90%），計算。
# ✅2015 1  新竹縣湖口鄉 覆蓋充足（80.74%），計算。
# ✅2015 1  新竹縣竹北市 覆蓋充足（116.31%），計算。
# ✅2015 1  新竹縣竹東鎮 覆蓋充足（131.36%），計算。
# ✅2015 1  新竹縣芎林鄉 覆蓋充足（117.35%），計算。
# ✅2015 1  新竹縣關西鎮 覆蓋充足（121.63%），計算。
# ✅2015 1  桃園市中壢區 覆蓋充足（92.35%），計算。
# ✅2015 1  桃園市八德區 覆蓋充足（69.32%），計算。
# ✅2015 1  桃園市大園區 覆蓋充足（104.01%），計算。
# ✅2015 1  桃園市大溪區 覆蓋充足（122.59%），計算。
# ✅2015 1  桃園市平鎮區 覆蓋充足（134.78%），計算。
# ⚠️2015 1 桃園市復興區 覆蓋不足（24.34%），略過。
# ✅2015 1  桃園市新屋區 覆蓋充足（91.84%），計算。
# ✅2015 1  桃園市桃園區 覆蓋充足（136.31%），計算。
# ✅2015 1  桃園市楊梅區 覆蓋充足（117.57%），計算。
# ✅2015 1  桃園市蘆竹區 覆蓋充足（109.58%），計算。
# ✅2015 1  桃園市觀音區 覆蓋充足（121.68%），計算。
# ✅2015 1  桃園市龍潭區 覆蓋充足（123.40%），計算。
# ✅2015 1  桃園市龜山區 覆蓋充足（81.98%），計算。
# ✅2015 1  臺中市北屯區 覆蓋充足（113.97%），計算。
# ✅2015 1  臺中市南屯區 覆蓋充足（115.59%），計算。
# ✅2015 1  臺中市后里區 覆蓋充足（122.88%），計算。
# ✅2015 1  臺中市外埔區 覆蓋充足（139.16%），計算。
# ✅2015 1  臺中市大安區 覆蓋充足（98.92%），計算。
# ✅2015 1  臺中市大甲區 覆蓋充足（98.68%），計算。
# ✅2015 1  臺中市大肚區 覆蓋充足（122.40%），計算。
# ✅2015 1  臺中市大里區 覆蓋充足（201.60%），計算。
# ✅2015 1  臺中市大雅區 覆蓋充足（142.76%），計算。
# ✅2015 1  臺中市太平區 覆蓋充足（77.74%），計算。
# ✅2015 1  臺中市新社區 覆蓋充足（71.36%），計算。
# ✅2015 1  臺中市東勢區 覆蓋充足（76.07%），計算。
# ✅2015 1  臺中市東區 覆蓋充足（173.74%），計算。
# ✅2015 1  臺中市梧棲區 覆蓋充足（106.42%），計算。
# ✅2015 1  臺中市沙鹿區 覆蓋充足（116.50%），計算。
# ✅2015 1  臺中市清水區 覆蓋充足（131.26%），計算。
# ✅2015 1  臺中市潭子區 覆蓋充足（90.67%），計算。
# ✅2015 1  臺中市烏日區 覆蓋充足（83.07%），計算。
# ✅2015 1  臺中市石岡區 覆蓋充足（65.77%），計算。
# ✅2015 1  臺中市神岡區 覆蓋充足（96.44%），計算。
# ✅2015 1  臺中市西區 覆蓋充足（184.52%），計算。
# ✅2015 1  臺中市西屯區 覆蓋充足（117.31%），計算。
# ✅2015 1  臺中市豐原區 覆蓋充足（112.61%），計算。
# ✅2015 1  臺中市霧峰區 覆蓋充足（97.40%），計算。
# ✅2015 1  臺中市龍井區 覆蓋充足（90.10%），計算。
# ✅2015 1  臺北市中山區 覆蓋充足（83.44%），計算。
# ✅2015 1  臺北市中正區 覆蓋充足（157.67%），計算。
# ✅2015 1  臺北市信義區 覆蓋充足（104.09%），計算。
# ✅2015 1  臺北市內湖區 覆蓋充足（73.33%），計算。
# ✅2015 1  臺北市北投區 覆蓋充足（121.74%），計算。
# ✅2015 1  臺北市南港區 覆蓋充足（106.73%），計算。
# ✅2015 1  臺北市士林區 覆蓋充足（113.33%），計算。
# ✅2015 1  臺北市文山區 覆蓋充足（149.95%），計算。
# ✅2015 1  臺北市松山區 覆蓋充足（135.30%），計算。
# ✅2015 1  臺北市萬華區 覆蓋充足（156.89%），計算。
# ✅2015 1  臺南市七股區 覆蓋充足（115.03%），計算。
# ✅2015 1  臺南市下營區 覆蓋充足（104.82%），計算。
# ✅2015 1  臺南市中西區 覆蓋充足（183.81%），計算。
# ✅2015 1  臺南市仁德區 覆蓋充足（139.38%），計算。
# ✅2015 1  臺南市佳里區 覆蓋充足（119.79%），計算。
# ✅2015 1  臺南市六甲區 覆蓋充足（87.67%），計算。
# ✅2015 1  臺南市北區 覆蓋充足（119.11%），計算。
# ✅2015 1  臺南市北門區 覆蓋充足（71.88%），計算。
# ✅2015 1  臺南市南化區 覆蓋充足（102.52%），計算。
# ✅2015 1  臺南市南區 覆蓋充足（83.80%），計算。
# ✅2015 1  臺南市善化區 覆蓋充足（131.49%），計算。
# ✅2015 1  臺南市大內區 覆蓋充足（98.88%），計算。
# ✅2015 1  臺南市學甲區 覆蓋充足（128.97%），計算。
# ✅2015 1  臺南市安南區 覆蓋充足（100.09%），計算。
# ✅2015 1  臺南市安定區 覆蓋充足（110.29%），計算。
# ✅2015 1  臺南市官田區 覆蓋充足（129.65%），計算。
# ✅2015 1  臺南市將軍區 覆蓋充足（122.57%），計算。
# ✅2015 1  臺南市山上區 覆蓋充足（84.78%），計算。
# ✅2015 1  臺南市左鎮區 覆蓋充足（112.64%），計算。
# ✅2015 1  臺南市後壁區 覆蓋充足（113.24%），計算。
# ✅2015 1  臺南市新化區 覆蓋充足（75.64%），計算。
# ✅2015 1  臺南市新市區 覆蓋充足（139.36%），計算。
# ✅2015 1  臺南市新營區 覆蓋充足（91.03%），計算。
# ✅2015 1  臺南市東區 覆蓋充足（90.83%），計算。
# ✅2015 1  臺南市東山區 覆蓋充足（94.44%），計算。
# ✅2015 1  臺南市柳營區 覆蓋充足（133.06%），計算。
# ✅2015 1  臺南市楠西區 覆蓋充足（118.20%），計算。
# ✅2015 1  臺南市歸仁區 覆蓋充足（106.58%），計算。
# ✅2015 1  臺南市永康區 覆蓋充足（114.73%），計算。
# ✅2015 1  臺南市玉井區 覆蓋充足（109.34%），計算。
# ✅2015 1  臺南市白河區 覆蓋充足（118.75%），計算。
# ✅2015 1  臺南市西港區 覆蓋充足（69.87%），計算。
# ✅2015 1  臺南市關廟區 覆蓋充足（109.40%），計算。
# ✅2015 1  臺南市鹽水區 覆蓋充足（113.55%），計算。
# ✅2015 1  臺南市麻豆區 覆蓋充足（85.36%），計算。
# ✅2015 1  臺南市龍崎區 覆蓋充足（112.77%），計算。
# ✅2015 1  臺東縣卑南鄉 覆蓋充足（60.54%），計算。
# ✅2015 1  臺東縣大武鄉 覆蓋充足（92.74%），計算。
# ✅2015 1  臺東縣太麻里鄉 覆蓋充足（90.54%），計算。
# ⚠️2015 1 臺東縣延平鄉 覆蓋不足（17.06%），略過。
# ✅2015 1  臺東縣成功鎮 覆蓋充足（80.06%），計算。
# ✅2015 1  臺東縣東河鄉 覆蓋充足（92.00%），計算。
# ✅2015 1  臺東縣池上鄉 覆蓋充足（103.50%），計算。
# ⚠️2015 1 臺東縣海端鄉 覆蓋不足（7.87%），略過。
# ✅2015 1  臺東縣綠島鄉 覆蓋充足（164.40%），計算。
# ✅2015 1  臺東縣臺東市 覆蓋充足（114.02%），計算。
# ✅2015 1  臺東縣蘭嶼鄉 覆蓋充足（123.88%），計算。
# ✅2015 1  臺東縣達仁鄉 覆蓋充足（72.97%），計算。
# ⚠️2015 1 臺東縣金峰鄉 覆蓋不足（33.25%），略過。
# ✅2015 1  臺東縣長濱鄉 覆蓋充足（93.05%），計算。
# ✅2015 1  臺東縣關山鎮 覆蓋充足（97.07%），計算。
# ✅2015 1  臺東縣鹿野鄉 覆蓋充足（88.13%），計算。
# ✅2015 1  花蓮縣光復鄉 覆蓋充足（105.96%），計算。
# ⚠️2015 1 花蓮縣卓溪鄉 覆蓋不足（14.57%），略過。
# ✅2015 1  花蓮縣吉安鄉 覆蓋充足（130.35%），計算。
# ✅2015 1  花蓮縣壽豐鄉 覆蓋充足（101.75%），計算。
# ✅2015 1  花蓮縣富里鄉 覆蓋充足（81.76%），計算。
# ✅2015 1  花蓮縣新城鄉 覆蓋充足（80.40%），計算。
# ✅2015 1  花蓮縣玉里鎮 覆蓋充足（122.08%），計算。
# ✅2015 1  花蓮縣瑞穗鄉 覆蓋充足（98.56%），計算。
# ⚠️2015 1 花蓮縣秀林鄉 覆蓋不足（18.78%），略過。
# ⚠️2015 1 花蓮縣花蓮市 覆蓋不足（37.85%），略過。
# ⚠️2015 1 花蓮縣萬榮鄉 覆蓋不足（17.77%），略過。
# ✅2015 1  花蓮縣豐濱鄉 覆蓋充足（124.71%），計算。
# ✅2015 1  花蓮縣鳳林鎮 覆蓋充足（98.30%），計算。
# ✅2015 1  苗栗縣三灣鄉 覆蓋充足（86.45%），計算。
# ✅2015 1  苗栗縣三義鄉 覆蓋充足（103.79%），計算。
# ✅2015 1  苗栗縣公館鄉 覆蓋充足（114.38%），計算。
# ✅2015 1  苗栗縣卓蘭鎮 覆蓋充足（75.66%），計算。
# ✅2015 1  苗栗縣南庄鄉 覆蓋充足（57.84%），計算。
# ⚠️2015 1 苗栗縣大湖鄉 覆蓋不足（38.64%），略過。
# ✅2015 1  苗栗縣後龍鎮 覆蓋充足（122.28%），計算。
# ⚠️2015 1 苗栗縣泰安鄉 覆蓋不足（1.94%），略過。
# ✅2015 1  苗栗縣獅潭鄉 覆蓋充足（103.29%），計算。
# ✅2015 1  苗栗縣竹南鎮 覆蓋充足（112.57%），計算。
# ✅2015 1  苗栗縣苑裡鎮 覆蓋充足（84.18%），計算。
# ✅2015 1  苗栗縣苗栗市 覆蓋充足（93.33%），計算。
# ✅2015 1  苗栗縣西湖鄉 覆蓋充足（114.46%），計算。
# ✅2015 1  苗栗縣通霄鎮 覆蓋充足（113.23%），計算。
# ✅2015 1  苗栗縣造橋鄉 覆蓋充足（121.21%），計算。
# ✅2015 1  苗栗縣銅鑼鄉 覆蓋充足（120.05%），計算。
# ✅2015 1  苗栗縣頭份市 覆蓋充足（154.94%），計算。
# ✅2015 1  苗栗縣頭屋鄉 覆蓋充足（90.85%），計算。
# ✅2015 1  雲林縣二崙鄉 覆蓋充足（96.36%），計算。
# ✅2015 1  雲林縣元長鄉 覆蓋充足（81.16%），計算。
# ✅2015 1  雲林縣北港鎮 覆蓋充足（84.40%），計算。
# ✅2015 1  雲林縣口湖鄉 覆蓋充足（106.49%），計算。
# ✅2015 1  雲林縣古坑鄉 覆蓋充足（91.63%），計算。
# ✅2015 1  雲林縣四湖鄉 覆蓋充足（113.61%），計算。
# ✅2015 1  雲林縣土庫鎮 覆蓋充足（121.79%），計算。
# ✅2015 1  雲林縣大埤鄉 覆蓋充足（79.32%），計算。
# ✅2015 1  雲林縣崙背鄉 覆蓋充足（61.51%），計算。
# ✅2015 1  雲林縣斗六市 覆蓋充足（127.62%），計算。
# ✅2015 1  雲林縣斗南鎮 覆蓋充足（121.28%），計算。
# ✅2015 1  雲林縣東勢鄉 覆蓋充足（126.06%），計算。
# ✅2015 1  雲林縣林內鄉 覆蓋充足（89.88%），計算。
# ✅2015 1  雲林縣水林鄉 覆蓋充足（128.70%），計算。
# ✅2015 1  雲林縣臺西鄉 覆蓋充足（101.19%），計算。
# ✅2015 1  雲林縣莿桐鄉 覆蓋充足（102.50%），計算。
# ✅2015 1  雲林縣虎尾鎮 覆蓋充足（119.96%），計算。
# ✅2015 1  雲林縣褒忠鄉 覆蓋充足（98.56%），計算。
# ✅2015 1  雲林縣西螺鎮 覆蓋充足（93.61%），計算。
# ✅2015 1  雲林縣麥寮鄉 覆蓋充足（112.12%），計算。
# ✅2015 1  高雄市三民區 覆蓋充足（69.01%），計算。
# ✅2015 1  高雄市仁武區 覆蓋充足（92.95%），計算。
# ✅2015 1  高雄市內門區 覆蓋充足（98.86%），計算。
# ✅2015 1  高雄市六龜區 覆蓋充足（84.46%），計算。
# ✅2015 1  高雄市前金區 覆蓋充足（596.19%），計算。
# ✅2015 1  高雄市前鎮區 覆蓋充足（165.67%），計算。
# ✅2015 1  高雄市大寮區 覆蓋充足（117.00%），計算。
# ✅2015 1  高雄市大樹區 覆蓋充足（121.51%），計算。
# ✅2015 1  高雄市大社區 覆蓋充足（92.44%），計算。
# ✅2015 1  高雄市小港區 覆蓋充足（108.63%），計算。
# ✅2015 1  高雄市岡山區 覆蓋充足（117.85%），計算。
# ✅2015 1  高雄市左營區 覆蓋充足（103.53%），計算。
# ✅2015 1  高雄市彌陀區 覆蓋充足（79.55%），計算。
# ✅2015 1  高雄市旗山區 覆蓋充足（136.24%），計算。
# ✅2015 1  高雄市旗津區 覆蓋充足（80.64%），計算。
# ✅2015 1  高雄市杉林區 覆蓋充足（112.98%），計算。
# ✅2015 1  高雄市林園區 覆蓋充足（98.20%），計算。
# ⚠️2015 1 高雄市桃源區 覆蓋不足（2.40%），略過。
# ✅2015 1  高雄市梓官區 覆蓋充足（98.91%），計算。
# ✅2015 1  高雄市楠梓區 覆蓋充足（165.36%），計算。
# ⚠️2015 1 高雄市橋頭區 覆蓋不足（48.07%），略過。
# ✅2015 1  高雄市永安區 覆蓋充足（131.11%），計算。
# ✅2015 1  高雄市湖內區 覆蓋充足（107.74%），計算。
# ✅2015 1  高雄市燕巢區 覆蓋充足（120.12%），計算。
# ✅2015 1  高雄市田寮區 覆蓋充足（103.84%），計算。
# ✅2015 1  高雄市甲仙區 覆蓋充足（66.19%），計算。
# ✅2015 1  高雄市美濃區 覆蓋充足（98.82%），計算。
# ✅2015 1  高雄市苓雅區 覆蓋充足（139.82%），計算。
# ⚠️2015 1 高雄市茂林區 覆蓋不足（9.70%），略過。
# ✅2015 1  高雄市茄萣區 覆蓋充足（68.70%），計算。
# ✅2015 1  高雄市路竹區 覆蓋充足（115.73%），計算。
# ✅2015 1  高雄市阿蓮區 覆蓋充足（67.10%），計算。
# ✅2015 1  高雄市鳥松區 覆蓋充足（142.28%），計算。
# ✅2015 1  高雄市鳳山區 覆蓋充足（83.99%），計算。
# ✅2015 1  高雄市鼓山區 覆蓋充足（158.89%），計算。
# ✅ 完成：NO 2015 week 1
# ✅2015 2  南投縣中寮鄉 覆蓋充足（97.70%），計算。
# ⚠️2015 2 南投縣仁愛鄉 覆蓋不足（5.76%），略過。
# ⚠️2015 2 南投縣信義鄉 覆蓋不足（1.65%），略過。
# ✅2015 2  南投縣南投市 覆蓋充足（114.11%），計算。
# ✅2015 2  南投縣名間鄉 覆蓋充足（118.21%），計算。
# ✅2015 2  南投縣國姓鄉 覆蓋充足（68.26%），計算。
# ✅2015 2  南投縣埔里鎮 覆蓋充足（95.67%），計算。
# ✅2015 2  南投縣水里鄉 覆蓋充足（62.89%），計算。
# ✅2015 2  南投縣竹山鎮 覆蓋充足（63.42%），計算。
# ✅2015 2  南投縣草屯鎮 覆蓋充足（90.14%），計算。
# ✅2015 2  南投縣集集鎮 覆蓋充足（88.45%），計算。
# ✅2015 2  南投縣魚池鄉 覆蓋充足（65.93%），計算。
# ✅2015 2  南投縣鹿谷鄉 覆蓋充足（81.95%），計算。
# ✅2015 2  嘉義市東區 覆蓋充足（78.49%），計算。
# ✅2015 2  嘉義市西區 覆蓋充足（156.84%），計算。
# ✅2015 2  嘉義縣中埔鄉 覆蓋充足（90.00%），計算。
# ✅2015 2  嘉義縣六腳鄉 覆蓋充足（112.78%），計算。
# ✅2015 2  嘉義縣大埔鄉 覆蓋充足（100.81%），計算。
# ✅2015 2  嘉義縣大林鎮 覆蓋充足（108.78%），計算。
# ✅2015 2  嘉義縣太保市 覆蓋充足（123.39%），計算。
# ✅2015 2  嘉義縣布袋鎮 覆蓋充足（88.91%），計算。
# ✅2015 2  嘉義縣新港鄉 覆蓋充足（106.18%），計算。
# ✅2015 2  嘉義縣朴子市 覆蓋充足（93.78%），計算。
# ✅2015 2  嘉義縣東石鄉 覆蓋充足（100.02%），計算。
# ✅2015 2  嘉義縣梅山鄉 覆蓋充足（58.82%），計算。
# ✅2015 2  嘉義縣民雄鄉 覆蓋充足（96.59%），計算。
# ✅2015 2  嘉義縣水上鄉 覆蓋充足（83.60%），計算。
# ✅2015 2  嘉義縣溪口鄉 覆蓋充足（144.53%），計算。
# ✅2015 2  嘉義縣番路鄉 覆蓋充足（83.37%），計算。
# ✅2015 2  嘉義縣竹崎鄉 覆蓋充足（59.75%），計算。
# ✅2015 2  嘉義縣義竹鄉 覆蓋充足（133.76%），計算。
# ✅2015 2  嘉義縣鹿草鄉 覆蓋充足（128.87%），計算。
# ✅2015 2  基隆市七堵區 覆蓋充足（125.04%），計算。
# ✅2015 2  基隆市仁愛區 覆蓋充足（257.15%），計算。
# ✅2015 2  基隆市信義區 覆蓋充足（110.51%），計算。
# ✅2015 2  基隆市安樂區 覆蓋充足（126.24%），計算。
# ✅2015 2  基隆市暖暖區 覆蓋充足（102.34%），計算。
# ✅2015 2  宜蘭縣三星鄉 覆蓋充足（119.74%），計算。
# ✅2015 2  宜蘭縣五結鄉 覆蓋充足（116.30%），計算。
# ✅2015 2  宜蘭縣冬山鄉 覆蓋充足（124.73%），計算。
# ⚠️2015 2 宜蘭縣南澳鄉 覆蓋不足（37.81%），略過。
# ✅2015 2  宜蘭縣員山鄉 覆蓋充足（82.76%），計算。
# ✅2015 2  宜蘭縣壯圍鄉 覆蓋充足（89.08%），計算。
# ⚠️2015 2 宜蘭縣大同鄉 覆蓋不足（19.78%），略過。
# ✅2015 2  宜蘭縣宜蘭市 覆蓋充足（153.97%），計算。
# ✅2015 2  宜蘭縣礁溪鄉 覆蓋充足（93.07%），計算。
# ✅2015 2  宜蘭縣蘇澳鎮 覆蓋充足（130.78%），計算。
# ✅2015 2  宜蘭縣頭城鎮 覆蓋充足（80.00%），計算。
# ✅2015 2  屏東縣三地門鄉 覆蓋充足（81.91%），計算。
# ✅2015 2  屏東縣九如鄉 覆蓋充足（108.69%），計算。
# ✅2015 2  屏東縣佳冬鄉 覆蓋充足（108.71%），計算。
# ✅2015 2  屏東縣來義鄉 覆蓋充足（57.75%），計算。
# ✅2015 2  屏東縣內埔鄉 覆蓋充足（121.47%），計算。
# ✅2015 2  屏東縣南州鄉 覆蓋充足（62.32%），計算。
# ✅2015 2  屏東縣屏東市 覆蓋充足（124.15%），計算。
# ✅2015 2  屏東縣崁頂鄉 覆蓋充足（138.82%），計算。
# ✅2015 2  屏東縣恆春鎮 覆蓋充足（99.71%），計算。
# ✅2015 2  屏東縣新園鄉 覆蓋充足（77.39%），計算。
# ✅2015 2  屏東縣新埤鄉 覆蓋充足（144.47%），計算。
# ✅2015 2  屏東縣春日鄉 覆蓋充足（82.84%），計算。
# ✅2015 2  屏東縣東港鎮 覆蓋充足（114.01%），計算。
# ✅2015 2  屏東縣枋寮鄉 覆蓋充足（96.78%），計算。
# ✅2015 2  屏東縣枋山鄉 覆蓋充足（259.16%），計算。
# ✅2015 2  屏東縣林邊鄉 覆蓋充足（137.18%），計算。
# ⚠️2015 2 屏東縣泰武鄉 覆蓋不足（47.19%），略過。
# ✅2015 2  屏東縣滿州鄉 覆蓋充足（117.85%），計算。
# ✅2015 2  屏東縣潮州鎮 覆蓋充足（82.63%），計算。
# ✅2015 2  屏東縣牡丹鄉 覆蓋充足（107.42%），計算。
# ✅2015 2  屏東縣獅子鄉 覆蓋充足（85.98%），計算。
# ✅2015 2  屏東縣琉球鄉 覆蓋充足（170.86%），計算。
# ✅2015 2  屏東縣瑪家鄉 覆蓋充足（94.96%），計算。
# ✅2015 2  屏東縣竹田鄉 覆蓋充足（118.56%），計算。
# ✅2015 2  屏東縣萬丹鄉 覆蓋充足（118.56%），計算。
# ✅2015 2  屏東縣萬巒鄉 覆蓋充足（57.76%），計算。
# ✅2015 2  屏東縣車城鄉 覆蓋充足（117.82%），計算。
# ✅2015 2  屏東縣里港鄉 覆蓋充足（100.82%），計算。
# ✅2015 2  屏東縣長治鄉 覆蓋充足（51.16%），計算。
# ⚠️2015 2 屏東縣霧臺鄉 覆蓋不足（3.84%），略過。
# ✅2015 2  屏東縣高樹鄉 覆蓋充足（87.02%），計算。
# ✅2015 2  屏東縣鹽埔鄉 覆蓋充足（118.79%），計算。
# ✅2015 2  屏東縣麟洛鄉 覆蓋充足（168.51%），計算。
# ✅2015 2  彰化縣二林鎮 覆蓋充足（101.64%），計算。
# ✅2015 2  彰化縣二水鄉 覆蓋充足（131.73%），計算。
# ✅2015 2  彰化縣伸港鄉 覆蓋充足（99.57%），計算。
# ✅2015 2  彰化縣北斗鎮 覆蓋充足（118.61%），計算。
# ✅2015 2  彰化縣和美鎮 覆蓋充足（122.71%），計算。
# ✅2015 2  彰化縣員林市 覆蓋充足（59.44%），計算。
# ✅2015 2  彰化縣埔心鄉 覆蓋充足（55.82%），計算。
# ✅2015 2  彰化縣埔鹽鄉 覆蓋充足（119.96%），計算。
# ✅2015 2  彰化縣埤頭鄉 覆蓋充足（137.86%），計算。
# ✅2015 2  彰化縣大城鄉 覆蓋充足（110.56%），計算。
# ✅2015 2  彰化縣大村鄉 覆蓋充足（153.86%），計算。
# ✅2015 2  彰化縣彰化市 覆蓋充足（71.25%），計算。
# ✅2015 2  彰化縣永靖鄉 覆蓋充足（115.44%），計算。
# ✅2015 2  彰化縣溪州鄉 覆蓋充足（118.39%），計算。
# ✅2015 2  彰化縣溪湖鎮 覆蓋充足（150.99%），計算。
# ✅2015 2  彰化縣田中鎮 覆蓋充足（68.00%），計算。
# ✅2015 2  彰化縣田尾鄉 覆蓋充足（94.82%），計算。
# ✅2015 2  彰化縣社頭鄉 覆蓋充足（130.46%），計算。
# ✅2015 2  彰化縣福興鄉 覆蓋充足（161.04%），計算。
# ✅2015 2  彰化縣秀水鄉 覆蓋充足（80.55%），計算。
# ✅2015 2  彰化縣竹塘鄉 覆蓋充足（111.85%），計算。
# ✅2015 2  彰化縣線西鄉 覆蓋充足（113.73%），計算。
# ✅2015 2  彰化縣芬園鄉 覆蓋充足（152.98%），計算。
# ✅2015 2  彰化縣花壇鄉 覆蓋充足（130.30%），計算。
# ✅2015 2  彰化縣芳苑鄉 覆蓋充足（104.76%），計算。
# ✅2015 2  彰化縣鹿港鎮 覆蓋充足（84.69%），計算。
# ✅2015 2  新北市三峽區 覆蓋充足（86.50%），計算。
# ✅2015 2  新北市三芝區 覆蓋充足（86.75%），計算。
# ✅2015 2  新北市三重區 覆蓋充足（65.14%），計算。
# ✅2015 2  新北市中和區 覆蓋充足（120.58%），計算。
# ✅2015 2  新北市五股區 覆蓋充足（102.37%），計算。
# ✅2015 2  新北市八里區 覆蓋充足（117.87%），計算。
# ✅2015 2  新北市土城區 覆蓋充足（117.38%），計算。
# ✅2015 2  新北市坪林區 覆蓋充足（69.61%），計算。
# ✅2015 2  新北市平溪區 覆蓋充足（131.69%），計算。
# ✅2015 2  新北市新店區 覆蓋充足（96.68%），計算。
# ✅2015 2  新北市新莊區 覆蓋充足（169.91%），計算。
# ✅2015 2  新北市板橋區 覆蓋充足（110.09%），計算。
# ✅2015 2  新北市林口區 覆蓋充足（129.46%），計算。
# ✅2015 2  新北市樹林區 覆蓋充足（110.11%），計算。
# ✅2015 2  新北市永和區 覆蓋充足（190.21%），計算。
# ✅2015 2  新北市汐止區 覆蓋充足（114.21%），計算。
# ✅2015 2  新北市淡水區 覆蓋充足（96.16%），計算。
# ✅2015 2  新北市深坑區 覆蓋充足（111.86%），計算。
# ⚠️2015 2 新北市烏來區 覆蓋不足（31.61%），略過。
# ✅2015 2  新北市瑞芳區 覆蓋充足（97.31%），計算。
# ✅2015 2  新北市石碇區 覆蓋充足（107.30%），計算。
# ✅2015 2  新北市石門區 覆蓋充足（110.52%），計算。
# ✅2015 2  新北市萬里區 覆蓋充足（110.56%），計算。
# ✅2015 2  新北市蘆洲區 覆蓋充足（151.81%），計算。
# ✅2015 2  新北市貢寮區 覆蓋充足（115.08%），計算。
# ✅2015 2  新北市金山區 覆蓋充足（98.16%），計算。
# ✅2015 2  新北市雙溪區 覆蓋充足（104.53%），計算。
# ✅2015 2  新北市鶯歌區 覆蓋充足（107.27%），計算。
# ✅2015 2  新竹市北區 覆蓋充足（99.36%），計算。
# ✅2015 2  新竹市東區 覆蓋充足（68.33%），計算。
# ✅2015 2  新竹市香山區 覆蓋充足（87.97%），計算。
# ⚠️2015 2 新竹縣五峰鄉 覆蓋不足（22.31%），略過。
# ✅2015 2  新竹縣北埔鄉 覆蓋充足（87.72%），計算。
# ✅2015 2  新竹縣寶山鄉 覆蓋充足（109.37%），計算。
# ⚠️2015 2 新竹縣尖石鄉 覆蓋不足（11.20%），略過。
# ✅2015 2  新竹縣峨眉鄉 覆蓋充足（125.87%），計算。
# ✅2015 2  新竹縣新埔鎮 覆蓋充足（97.34%），計算。
# ✅2015 2  新竹縣新豐鄉 覆蓋充足（117.40%），計算。
# ✅2015 2  新竹縣橫山鄉 覆蓋充足（107.90%），計算。
# ✅2015 2  新竹縣湖口鄉 覆蓋充足（80.74%），計算。
# ✅2015 2  新竹縣竹北市 覆蓋充足（116.31%），計算。
# ✅2015 2  新竹縣竹東鎮 覆蓋充足（131.36%），計算。
# ✅2015 2  新竹縣芎林鄉 覆蓋充足（117.35%），計算。
# ✅2015 2  新竹縣關西鎮 覆蓋充足（121.63%），計算。
# ✅2015 2  桃園市中壢區 覆蓋充足（92.35%），計算。
# ✅2015 2  桃園市八德區 覆蓋充足（69.32%），計算。
# ✅2015 2  桃園市大園區 覆蓋充足（104.01%），計算。
# ✅2015 2  桃園市大溪區 覆蓋充足（122.59%），計算。
# ✅2015 2  桃園市平鎮區 覆蓋充足（134.78%），計算。
# ⚠️2015 2 桃園市復興區 覆蓋不足（24.34%），略過。
# ✅2015 2  桃園市新屋區 覆蓋充足（91.84%），計算。
# ✅2015 2  桃園市桃園區 覆蓋充足（136.31%），計算。
# ✅2015 2  桃園市楊梅區 覆蓋充足（117.57%），計算。
# ✅2015 2  桃園市蘆竹區 覆蓋充足（109.58%），計算。
# ✅2015 2  桃園市觀音區 覆蓋充足（121.68%），計算。
# ✅2015 2  桃園市龍潭區 覆蓋充足（123.40%），計算。
# ✅2015 2  桃園市龜山區 覆蓋充足（81.98%），計算。
# ✅2015 2  臺中市北屯區 覆蓋充足（113.97%），計算。
# ✅2015 2  臺中市南屯區 覆蓋充足（115.59%），計算。
# ✅2015 2  臺中市后里區 覆蓋充足（122.88%），計算。
# ✅2015 2  臺中市外埔區 覆蓋充足（139.16%），計算。
# ✅2015 2  臺中市大安區 覆蓋充足（98.92%），計算。
# ✅2015 2  臺中市大甲區 覆蓋充足（98.68%），計算。
# ✅2015 2  臺中市大肚區 覆蓋充足（122.40%），計算。
# ✅2015 2  臺中市大里區 覆蓋充足（201.60%），計算。
# ✅2015 2  臺中市大雅區 覆蓋充足（142.76%），計算。
# ✅2015 2  臺中市太平區 覆蓋充足（77.74%），計算。
# ✅2015 2  臺中市新社區 覆蓋充足（71.36%），計算。
# ✅2015 2  臺中市東勢區 覆蓋充足（76.07%），計算。
# ✅2015 2  臺中市東區 覆蓋充足（173.74%），計算。
# ✅2015 2  臺中市梧棲區 覆蓋充足（106.42%），計算。
# ✅2015 2  臺中市沙鹿區 覆蓋充足（116.50%），計算。
# ✅2015 2  臺中市清水區 覆蓋充足（131.26%），計算。
# ✅2015 2  臺中市潭子區 覆蓋充足（90.67%），計算。
# ✅2015 2  臺中市烏日區 覆蓋充足（83.07%），計算。
# ✅2015 2  臺中市石岡區 覆蓋充足（65.77%），計算。
# ✅2015 2  臺中市神岡區 覆蓋充足（96.44%），計算。
# ✅2015 2  臺中市西區 覆蓋充足（184.52%），計算。
# ✅2015 2  臺中市西屯區 覆蓋充足（117.31%），計算。
# ✅2015 2  臺中市豐原區 覆蓋充足（112.61%），計算。
# ✅2015 2  臺中市霧峰區 覆蓋充足（97.40%），計算。
# ✅2015 2  臺中市龍井區 覆蓋充足（90.10%），計算。
# ✅2015 2  臺北市中山區 覆蓋充足（83.44%），計算。
# ✅2015 2  臺北市中正區 覆蓋充足（157.67%），計算。
# ✅2015 2  臺北市信義區 覆蓋充足（104.09%），計算。
# ✅2015 2  臺北市內湖區 覆蓋充足（73.33%），計算。
# ✅2015 2  臺北市北投區 覆蓋充足（121.74%），計算。
# ✅2015 2  臺北市南港區 覆蓋充足（106.73%），計算。
# ✅2015 2  臺北市士林區 覆蓋充足（113.33%），計算。
# ✅2015 2  臺北市文山區 覆蓋充足（149.95%），計算。
# ✅2015 2  臺北市松山區 覆蓋充足（135.30%），計算。
# ✅2015 2  臺北市萬華區 覆蓋充足（156.89%），計算。
# ✅2015 2  臺南市七股區 覆蓋充足（115.03%），計算。
# ✅2015 2  臺南市下營區 覆蓋充足（104.82%），計算。
# ✅2015 2  臺南市中西區 覆蓋充足（183.81%），計算。
# ✅2015 2  臺南市仁德區 覆蓋充足（139.38%），計算。
# ✅2015 2  臺南市佳里區 覆蓋充足（119.79%），計算。
# ✅2015 2  臺南市六甲區 覆蓋充足（87.67%），計算。
# ✅2015 2  臺南市北區 覆蓋充足（119.11%），計算。
# ✅2015 2  臺南市北門區 覆蓋充足（71.88%），計算。
# ✅2015 2  臺南市南化區 覆蓋充足（102.52%），計算。
# ✅2015 2  臺南市南區 覆蓋充足（83.80%），計算。
# ✅2015 2  臺南市善化區 覆蓋充足（131.49%），計算。
# ✅2015 2  臺南市大內區 覆蓋充足（98.88%），計算。
# ✅2015 2  臺南市學甲區 覆蓋充足（128.97%），計算。
# ✅2015 2  臺南市安南區 覆蓋充足（100.09%），計算。
# ✅2015 2  臺南市安定區 覆蓋充足（110.29%），計算。
# ✅2015 2  臺南市官田區 覆蓋充足（129.65%），計算。
# ✅2015 2  臺南市將軍區 覆蓋充足（122.57%），計算。
# ✅2015 2  臺南市山上區 覆蓋充足（84.78%），計算。
# ✅2015 2  臺南市左鎮區 覆蓋充足（112.64%），計算。
# ✅2015 2  臺南市後壁區 覆蓋充足（113.24%），計算。
# ✅2015 2  臺南市新化區 覆蓋充足（75.64%），計算。
# ✅2015 2  臺南市新市區 覆蓋充足（139.36%），計算。
# ✅2015 2  臺南市新營區 覆蓋充足（91.03%），計算。
# ✅2015 2  臺南市東區 覆蓋充足（90.83%），計算。
# ✅2015 2  臺南市東山區 覆蓋充足（94.44%），計算。
# ✅2015 2  臺南市柳營區 覆蓋充足（133.06%），計算。
# ✅2015 2  臺南市楠西區 覆蓋充足（118.20%），計算。
# ✅2015 2  臺南市歸仁區 覆蓋充足（106.58%），計算。
# ✅2015 2  臺南市永康區 覆蓋充足（114.73%），計算。
# ✅2015 2  臺南市玉井區 覆蓋充足（109.34%），計算。
# ✅2015 2  臺南市白河區 覆蓋充足（118.75%），計算。
# ✅2015 2  臺南市西港區 覆蓋充足（69.87%），計算。
# ✅2015 2  臺南市關廟區 覆蓋充足（109.40%），計算。
# ✅2015 2  臺南市鹽水區 覆蓋充足（113.55%），計算。
# ✅2015 2  臺南市麻豆區 覆蓋充足（85.36%），計算。
# ✅2015 2  臺南市龍崎區 覆蓋充足（112.77%），計算。
# ✅2015 2  臺東縣卑南鄉 覆蓋充足（60.54%），計算。
# ✅2015 2  臺東縣大武鄉 覆蓋充足（92.74%），計算。
# ✅2015 2  臺東縣太麻里鄉 覆蓋充足（90.54%），計算。
# ⚠️2015 2 臺東縣延平鄉 覆蓋不足（17.06%），略過。
# ✅2015 2  臺東縣成功鎮 覆蓋充足（80.06%），計算。
# ✅2015 2  臺東縣東河鄉 覆蓋充足（92.00%），計算。
# ✅2015 2  臺東縣池上鄉 覆蓋充足（103.50%），計算。
# ⚠️2015 2 臺東縣海端鄉 覆蓋不足（7.87%），略過。
# ✅2015 2  臺東縣綠島鄉 覆蓋充足（164.40%），計算。
# ✅2015 2  臺東縣臺東市 覆蓋充足（114.02%），計算。
# ✅2015 2  臺東縣蘭嶼鄉 覆蓋充足（123.88%），計算。
# ✅2015 2  臺東縣達仁鄉 覆蓋充足（72.97%），計算。
# ⚠️2015 2 臺東縣金峰鄉 覆蓋不足（33.25%），略過。
# ✅2015 2  臺東縣長濱鄉 覆蓋充足（93.05%），計算。
# ✅2015 2  臺東縣關山鎮 覆蓋充足（97.07%），計算。
# ✅2015 2  臺東縣鹿野鄉 覆蓋充足（88.13%），計算。
# ✅2015 2  花蓮縣光復鄉 覆蓋充足（105.96%），計算。
# ⚠️2015 2 花蓮縣卓溪鄉 覆蓋不足（14.57%），略過。
# ✅2015 2  花蓮縣吉安鄉 覆蓋充足（130.35%），計算。
# ✅2015 2  花蓮縣壽豐鄉 覆蓋充足（101.75%），計算。
# ✅2015 2  花蓮縣富里鄉 覆蓋充足（81.76%），計算。
# ✅2015 2  花蓮縣新城鄉 覆蓋充足（80.40%），計算。
# ✅2015 2  花蓮縣玉里鎮 覆蓋充足（122.08%），計算。
# ✅2015 2  花蓮縣瑞穗鄉 覆蓋充足（98.56%），計算。
# ⚠️2015 2 花蓮縣秀林鄉 覆蓋不足（18.78%），略過。
# ⚠️2015 2 花蓮縣花蓮市 覆蓋不足（37.85%），略過。
# ⚠️2015 2 花蓮縣萬榮鄉 覆蓋不足（17.77%），略過。
# ✅2015 2  花蓮縣豐濱鄉 覆蓋充足（124.71%），計算。
# ✅2015 2  花蓮縣鳳林鎮 覆蓋充足（98.30%），計算。
# ✅2015 2  苗栗縣三灣鄉 覆蓋充足（86.45%），計算。
# ✅2015 2  苗栗縣三義鄉 覆蓋充足（103.79%），計算。
# ✅2015 2  苗栗縣公館鄉 覆蓋充足（114.38%），計算。
# ✅2015 2  苗栗縣卓蘭鎮 覆蓋充足（75.66%），計算。
# ✅2015 2  苗栗縣南庄鄉 覆蓋充足（57.84%），計算。
# ⚠️2015 2 苗栗縣大湖鄉 覆蓋不足（38.64%），略過。
# ✅2015 2  苗栗縣後龍鎮 覆蓋充足（122.28%），計算。
# ⚠️2015 2 苗栗縣泰安鄉 覆蓋不足（1.94%），略過。
# ✅2015 2  苗栗縣獅潭鄉 覆蓋充足（103.29%），計算。
# ✅2015 2  苗栗縣竹南鎮 覆蓋充足（112.57%），計算。
# ✅2015 2  苗栗縣苑裡鎮 覆蓋充足（84.18%），計算。
# ✅2015 2  苗栗縣苗栗市 覆蓋充足（93.33%），計算。
# ✅2015 2  苗栗縣西湖鄉 覆蓋充足（114.46%），計算。
# ✅2015 2  苗栗縣通霄鎮 覆蓋充足（113.23%），計算。
# ✅2015 2  苗栗縣造橋鄉 覆蓋充足（121.21%），計算。
# ✅2015 2  苗栗縣銅鑼鄉 覆蓋充足（120.05%），計算。
# ✅2015 2  苗栗縣頭份市 覆蓋充足（154.94%），計算。
# ✅2015 2  苗栗縣頭屋鄉 覆蓋充足（90.85%），計算。
# ✅2015 2  雲林縣二崙鄉 覆蓋充足（96.36%），計算。
# ✅2015 2  雲林縣元長鄉 覆蓋充足（81.16%），計算。
# ✅2015 2  雲林縣北港鎮 覆蓋充足（84.40%），計算。
# ✅2015 2  雲林縣口湖鄉 覆蓋充足（106.49%），計算。
# ✅2015 2  雲林縣古坑鄉 覆蓋充足（91.63%），計算。
# ✅2015 2  雲林縣四湖鄉 覆蓋充足（113.61%），計算。
# ✅2015 2  雲林縣土庫鎮 覆蓋充足（121.79%），計算。
# ✅2015 2  雲林縣大埤鄉 覆蓋充足（79.32%），計算。
# ✅2015 2  雲林縣崙背鄉 覆蓋充足（61.51%），計算。
# ✅2015 2  雲林縣斗六市 覆蓋充足（127.62%），計算。
# ✅2015 2  雲林縣斗南鎮 覆蓋充足（121.28%），計算。
# ✅2015 2  雲林縣東勢鄉 覆蓋充足（126.06%），計算。
# ✅2015 2  雲林縣林內鄉 覆蓋充足（89.88%），計算。
# ✅2015 2  雲林縣水林鄉 覆蓋充足（128.70%），計算。
# ✅2015 2  雲林縣臺西鄉 覆蓋充足（101.19%），計算。
# ✅2015 2  雲林縣莿桐鄉 覆蓋充足（102.50%），計算。
# ✅2015 2  雲林縣虎尾鎮 覆蓋充足（119.96%），計算。
# ✅2015 2  雲林縣褒忠鄉 覆蓋充足（98.56%），計算。
# ✅2015 2  雲林縣西螺鎮 覆蓋充足（93.61%），計算。
# ✅2015 2  雲林縣麥寮鄉 覆蓋充足（112.12%），計算。
# ✅2015 2  高雄市三民區 覆蓋充足（69.01%），計算。
# ✅2015 2  高雄市仁武區 覆蓋充足（92.95%），計算。
# ✅2015 2  高雄市內門區 覆蓋充足（98.86%），計算。
# ✅2015 2  高雄市六龜區 覆蓋充足（84.46%），計算。
# ✅2015 2  高雄市前金區 覆蓋充足（596.19%），計算。
# ✅2015 2  高雄市前鎮區 覆蓋充足（165.67%），計算。
# ✅2015 2  高雄市大寮區 覆蓋充足（117.00%），計算。
# ✅2015 2  高雄市大樹區 覆蓋充足（121.51%），計算。
# ✅2015 2  高雄市大社區 覆蓋充足（92.44%），計算。
# ✅2015 2  高雄市小港區 覆蓋充足（108.63%），計算。
# ✅2015 2  高雄市岡山區 覆蓋充足（117.85%），計算。
# ✅2015 2  高雄市左營區 覆蓋充足（103.53%），計算。
# ✅2015 2  高雄市彌陀區 覆蓋充足（79.55%），計算。
# ✅2015 2  高雄市旗山區 覆蓋充足（136.24%），計算。
# ✅2015 2  高雄市旗津區 覆蓋充足（80.64%），計算。
# ✅2015 2  高雄市杉林區 覆蓋充足（112.98%），計算。
# ✅2015 2  高雄市林園區 覆蓋充足（98.20%），計算。
# ⚠️2015 2 高雄市桃源區 覆蓋不足（2.40%），略過。
# ✅2015 2  高雄市梓官區 覆蓋充足（98.91%），計算。
# ✅2015 2  高雄市楠梓區 覆蓋充足（165.36%），計算。
# ⚠️2015 2 高雄市橋頭區 覆蓋不足（48.07%），略過。
# ✅2015 2  高雄市永安區 覆蓋充足（131.11%），計算。
# ✅2015 2  高雄市湖內區 覆蓋充足（107.74%），計算。
# ✅2015 2  高雄市燕巢區 覆蓋充足（120.12%），計算。
# ✅2015 2  高雄市田寮區 覆蓋充足（103.84%），計算。
# ✅2015 2  高雄市甲仙區 覆蓋充足（66.19%），計算。
# ✅2015 2  高雄市美濃區 覆蓋充足（98.82%），計算。
# ✅2015 2  高雄市苓雅區 覆蓋充足（139.82%），計算。
# ⚠️2015 2 高雄市茂林區 覆蓋不足（9.70%），略過。
# ✅2015 2  高雄市茄萣區 覆蓋充足（68.70%），計算。
# ✅2015 2  高雄市路竹區 覆蓋充足（115.73%），計算。
# ✅2015 2  高雄市阿蓮區 覆蓋充足（67.10%），計算。
# ✅2015 2  高雄市鳥松區 覆蓋充足（142.28%），計算。
# ✅2015 2  高雄市鳳山區 覆蓋充足（83.99%），計算。
# ✅2015 2  高雄市鼓山區 覆蓋充足（158.89%），計算。
# ✅ 完成：NO 2015 week 2
# ✅2015 3  南投縣中寮鄉 覆蓋充足（97.70%），計算。
# ⚠️2015 3 南投縣仁愛鄉 覆蓋不足（5.76%），略過。
# ⚠️2015 3 南投縣信義鄉 覆蓋不足（1.65%），略過。
# ✅2015 3  南投縣南投市 覆蓋充足（114.11%），計算。
# ✅2015 3  南投縣名間鄉 覆蓋充足（118.21%），計算。
# ✅2015 3  南投縣國姓鄉 覆蓋充足（68.26%），計算。
# ✅2015 3  南投縣埔里鎮 覆蓋充足（95.67%），計算。
# ✅2015 3  南投縣水里鄉 覆蓋充足（62.89%），計算。
# ✅2015 3  南投縣竹山鎮 覆蓋充足（63.42%），計算。
# ✅2015 3  南投縣草屯鎮 覆蓋充足（90.14%），計算。
# ✅2015 3  南投縣集集鎮 覆蓋充足（88.45%），計算。
# ✅2015 3  南投縣魚池鄉 覆蓋充足（65.93%），計算。
# ✅2015 3  南投縣鹿谷鄉 覆蓋充足（81.95%），計算。
# ✅2015 3  嘉義市東區 覆蓋充足（78.49%），計算。
# ✅2015 3  嘉義市西區 覆蓋充足（156.84%），計算。
# ✅2015 3  嘉義縣中埔鄉 覆蓋充足（90.00%），計算。
# ✅2015 3  嘉義縣六腳鄉 覆蓋充足（112.78%），計算。
# ✅2015 3  嘉義縣大埔鄉 覆蓋充足（100.81%），計算。
# ✅2015 3  嘉義縣大林鎮 覆蓋充足（108.78%），計算。
# ✅2015 3  嘉義縣太保市 覆蓋充足（123.39%），計算。
# ✅2015 3  嘉義縣布袋鎮 覆蓋充足（88.91%），計算。
# ✅2015 3  嘉義縣新港鄉 覆蓋充足（106.18%），計算。
# ✅2015 3  嘉義縣朴子市 覆蓋充足（93.78%），計算。
# ✅2015 3  嘉義縣東石鄉 覆蓋充足（100.02%），計算。
# ✅2015 3  嘉義縣梅山鄉 覆蓋充足（58.82%），計算。
# ✅2015 3  嘉義縣民雄鄉 覆蓋充足（96.59%），計算。
# ✅2015 3  嘉義縣水上鄉 覆蓋充足（83.60%），計算。
# ✅2015 3  嘉義縣溪口鄉 覆蓋充足（144.53%），計算。
# ✅2015 3  嘉義縣番路鄉 覆蓋充足（83.37%），計算。
# ✅2015 3  嘉義縣竹崎鄉 覆蓋充足（59.75%），計算。
# ✅2015 3  嘉義縣義竹鄉 覆蓋充足（133.76%），計算。
# ✅2015 3  嘉義縣鹿草鄉 覆蓋充足（128.87%），計算。
# ✅2015 3  基隆市七堵區 覆蓋充足（125.04%），計算。
# ✅2015 3  基隆市仁愛區 覆蓋充足（257.15%），計算。
# ✅2015 3  基隆市信義區 覆蓋充足（110.51%），計算。
# ✅2015 3  基隆市安樂區 覆蓋充足（126.24%），計算。
# ✅2015 3  基隆市暖暖區 覆蓋充足（102.34%），計算。
# ✅2015 3  宜蘭縣三星鄉 覆蓋充足（119.74%），計算。
# ✅2015 3  宜蘭縣五結鄉 覆蓋充足（116.30%），計算。
# ✅2015 3  宜蘭縣冬山鄉 覆蓋充足（124.73%），計算。
# ⚠️2015 3 宜蘭縣南澳鄉 覆蓋不足（37.81%），略過。
# ✅2015 3  宜蘭縣員山鄉 覆蓋充足（82.76%），計算。
# ✅2015 3  宜蘭縣壯圍鄉 覆蓋充足（89.08%），計算。
# ⚠️2015 3 宜蘭縣大同鄉 覆蓋不足（19.78%），略過。
# ✅2015 3  宜蘭縣宜蘭市 覆蓋充足（153.97%），計算。
# ✅2015 3  宜蘭縣礁溪鄉 覆蓋充足（93.07%），計算。
# ✅2015 3  宜蘭縣蘇澳鎮 覆蓋充足（130.78%），計算。
# ✅2015 3  宜蘭縣頭城鎮 覆蓋充足（80.00%），計算。
# ✅2015 3  屏東縣三地門鄉 覆蓋充足（81.91%），計算。
# ✅2015 3  屏東縣九如鄉 覆蓋充足（108.69%），計算。
# ✅2015 3  屏東縣佳冬鄉 覆蓋充足（108.71%），計算。
# ✅2015 3  屏東縣來義鄉 覆蓋充足（57.75%），計算。
# ✅2015 3  屏東縣內埔鄉 覆蓋充足（121.47%），計算。
# ✅2015 3  屏東縣南州鄉 覆蓋充足（62.32%），計算。
# ✅2015 3  屏東縣屏東市 覆蓋充足（124.15%），計算。
# ✅2015 3  屏東縣崁頂鄉 覆蓋充足（138.82%），計算。
# ✅2015 3  屏東縣恆春鎮 覆蓋充足（99.71%），計算。
# ✅2015 3  屏東縣新園鄉 覆蓋充足（77.39%），計算。
# ✅2015 3  屏東縣新埤鄉 覆蓋充足（144.47%），計算。
# ✅2015 3  屏東縣春日鄉 覆蓋充足（82.84%），計算。
# ✅2015 3  屏東縣東港鎮 覆蓋充足（114.01%），計算。
# ✅2015 3  屏東縣枋寮鄉 覆蓋充足（96.78%），計算。
# ✅2015 3  屏東縣枋山鄉 覆蓋充足（259.16%），計算。
# ✅2015 3  屏東縣林邊鄉 覆蓋充足（137.18%），計算。
# ⚠️2015 3 屏東縣泰武鄉 覆蓋不足（47.19%），略過。
# ✅2015 3  屏東縣滿州鄉 覆蓋充足（117.85%），計算。
# ✅2015 3  屏東縣潮州鎮 覆蓋充足（82.63%），計算。
# ✅2015 3  屏東縣牡丹鄉 覆蓋充足（107.42%），計算。
# ✅2015 3  屏東縣獅子鄉 覆蓋充足（85.98%），計算。
# ✅2015 3  屏東縣琉球鄉 覆蓋充足（170.86%），計算。
# ✅2015 3  屏東縣瑪家鄉 覆蓋充足（94.96%），計算。
# ✅2015 3  屏東縣竹田鄉 覆蓋充足（118.56%），計算。
# ✅2015 3  屏東縣萬丹鄉 覆蓋充足（118.56%），計算。
# ✅2015 3  屏東縣萬巒鄉 覆蓋充足（57.76%），計算。
# ✅2015 3  屏東縣車城鄉 覆蓋充足（117.82%），計算。
# ✅2015 3  屏東縣里港鄉 覆蓋充足（100.82%），計算。
# ✅2015 3  屏東縣長治鄉 覆蓋充足（51.16%），計算。
# ⚠️2015 3 屏東縣霧臺鄉 覆蓋不足（3.84%），略過。
# ✅2015 3  屏東縣高樹鄉 覆蓋充足（87.02%），計算。
# ✅2015 3  屏東縣鹽埔鄉 覆蓋充足（118.79%），計算。
# ✅2015 3  屏東縣麟洛鄉 覆蓋充足（168.51%），計算。
# ✅2015 3  彰化縣二林鎮 覆蓋充足（101.64%），計算。
# ✅2015 3  彰化縣二水鄉 覆蓋充足（131.73%），計算。
# ✅2015 3  彰化縣伸港鄉 覆蓋充足（99.57%），計算。
# ✅2015 3  彰化縣北斗鎮 覆蓋充足（118.61%），計算。
# ✅2015 3  彰化縣和美鎮 覆蓋充足（122.71%），計算。
# ✅2015 3  彰化縣員林市 覆蓋充足（59.44%），計算。
# ✅2015 3  彰化縣埔心鄉 覆蓋充足（55.82%），計算。
# ✅2015 3  彰化縣埔鹽鄉 覆蓋充足（119.96%），計算。
# ✅2015 3  彰化縣埤頭鄉 覆蓋充足（137.86%），計算。
# ✅2015 3  彰化縣大城鄉 覆蓋充足（110.56%），計算。
# ✅2015 3  彰化縣大村鄉 覆蓋充足（153.86%），計算。
# ✅2015 3  彰化縣彰化市 覆蓋充足（71.25%），計算。
# ✅2015 3  彰化縣永靖鄉 覆蓋充足（115.44%），計算。
# ✅2015 3  彰化縣溪州鄉 覆蓋充足（118.39%），計算。
# ✅2015 3  彰化縣溪湖鎮 覆蓋充足（150.99%），計算。
# ✅2015 3  彰化縣田中鎮 覆蓋充足（68.00%），計算。
# ✅2015 3  彰化縣田尾鄉 覆蓋充足（94.82%），計算。
# ✅2015 3  彰化縣社頭鄉 覆蓋充足（130.46%），計算。
# ✅2015 3  彰化縣福興鄉 覆蓋充足（161.04%），計算。
# ✅2015 3  彰化縣秀水鄉 覆蓋充足（80.55%），計算。
# ✅2015 3  彰化縣竹塘鄉 覆蓋充足（111.85%），計算。
# ✅2015 3  彰化縣線西鄉 覆蓋充足（113.73%），計算。
# ✅2015 3  彰化縣芬園鄉 覆蓋充足（152.98%），計算。
# ✅2015 3  彰化縣花壇鄉 覆蓋充足（130.30%），計算。
# ✅2015 3  彰化縣芳苑鄉 覆蓋充足（104.76%），計算。
# ✅2015 3  彰化縣鹿港鎮 覆蓋充足（84.69%），計算。
# ✅2015 3  新北市三峽區 覆蓋充足（86.50%），計算。
# ✅2015 3  新北市三芝區 覆蓋充足（86.75%），計算。
# ✅2015 3  新北市三重區 覆蓋充足（65.14%），計算。
# ✅2015 3  新北市中和區 覆蓋充足（120.58%），計算。
# ✅2015 3  新北市五股區 覆蓋充足（102.37%），計算。
# ✅2015 3  新北市八里區 覆蓋充足（117.87%），計算。
# ✅2015 3  新北市土城區 覆蓋充足（117.38%），計算。
# ✅2015 3  新北市坪林區 覆蓋充足（69.61%），計算。
# ✅2015 3  新北市平溪區 覆蓋充足（131.69%），計算。
# ✅2015 3  新北市新店區 覆蓋充足（96.68%），計算。
# ✅2015 3  新北市新莊區 覆蓋充足（169.91%），計算。
# ✅2015 3  新北市板橋區 覆蓋充足（110.09%），計算。
# ✅2015 3  新北市林口區 覆蓋充足（129.46%），計算。
# ✅2015 3  新北市樹林區 覆蓋充足（110.11%），計算。
# ✅2015 3  新北市永和區 覆蓋充足（190.21%），計算。
# ✅2015 3  新北市汐止區 覆蓋充足（114.21%），計算。
# ✅2015 3  新北市淡水區 覆蓋充足（96.16%），計算。
# ✅2015 3  新北市深坑區 覆蓋充足（111.86%），計算。
# ⚠️2015 3 新北市烏來區 覆蓋不足（31.61%），略過。
# ✅2015 3  新北市瑞芳區 覆蓋充足（97.31%），計算。
# ✅2015 3  新北市石碇區 覆蓋充足（107.30%），計算。
# ✅2015 3  新北市石門區 覆蓋充足（110.52%），計算。
# ✅2015 3  新北市萬里區 覆蓋充足（110.56%），計算。
# ✅2015 3  新北市蘆洲區 覆蓋充足（151.81%），計算。
# ✅2015 3  新北市貢寮區 覆蓋充足（115.08%），計算。
# ✅2015 3  新北市金山區 覆蓋充足（98.16%），計算。
# ✅2015 3  新北市雙溪區 覆蓋充足（104.53%），計算。
# ✅2015 3  新北市鶯歌區 覆蓋充足（107.27%），計算。
# ✅2015 3  新竹市北區 覆蓋充足（99.36%），計算。
# ✅2015 3  新竹市東區 覆蓋充足（68.33%），計算。
# ✅2015 3  新竹市香山區 覆蓋充足（87.97%），計算。
# ⚠️2015 3 新竹縣五峰鄉 覆蓋不足（22.31%），略過。
# ✅2015 3  新竹縣北埔鄉 覆蓋充足（87.72%），計算。
# ✅2015 3  新竹縣寶山鄉 覆蓋充足（109.37%），計算。
# ⚠️2015 3 新竹縣尖石鄉 覆蓋不足（11.20%），略過。
# ✅2015 3  新竹縣峨眉鄉 覆蓋充足（125.87%），計算。
# ✅2015 3  新竹縣新埔鎮 覆蓋充足（97.34%），計算。
# ✅2015 3  新竹縣新豐鄉 覆蓋充足（117.40%），計算。
# ✅2015 3  新竹縣橫山鄉 覆蓋充足（107.90%），計算。
# ✅2015 3  新竹縣湖口鄉 覆蓋充足（80.74%），計算。
# ✅2015 3  新竹縣竹北市 覆蓋充足（116.31%），計算。
# ✅2015 3  新竹縣竹東鎮 覆蓋充足（131.36%），計算。
# ✅2015 3  新竹縣芎林鄉 覆蓋充足（117.35%），計算。
# ✅2015 3  新竹縣關西鎮 覆蓋充足（121.63%），計算。
# ✅2015 3  桃園市中壢區 覆蓋充足（92.35%），計算。
# ✅2015 3  桃園市八德區 覆蓋充足（69.32%），計算。
# ✅2015 3  桃園市大園區 覆蓋充足（104.01%），計算。
# ✅2015 3  桃園市大溪區 覆蓋充足（122.59%），計算。
# ✅2015 3  桃園市平鎮區 覆蓋充足（134.78%），計算。
# ⚠️2015 3 桃園市復興區 覆蓋不足（24.34%），略過。
# ✅2015 3  桃園市新屋區 覆蓋充足（91.84%），計算。
# ✅2015 3  桃園市桃園區 覆蓋充足（136.31%），計算。
# ✅2015 3  桃園市楊梅區 覆蓋充足（117.57%），計算。
# ✅2015 3  桃園市蘆竹區 覆蓋充足（109.58%），計算。
# ✅2015 3  桃園市觀音區 覆蓋充足（121.68%），計算。
# ✅2015 3  桃園市龍潭區 覆蓋充足（123.40%），計算。
# ✅2015 3  桃園市龜山區 覆蓋充足（81.98%），計算。
# ✅2015 3  臺中市北屯區 覆蓋充足（113.97%），計算。
# ✅2015 3  臺中市南屯區 覆蓋充足（115.59%），計算。
# ✅2015 3  臺中市后里區 覆蓋充足（122.88%），計算。
# ✅2015 3  臺中市外埔區 覆蓋充足（139.16%），計算。
# ✅2015 3  臺中市大安區 覆蓋充足（98.92%），計算。
# ✅2015 3  臺中市大甲區 覆蓋充足（98.68%），計算。
# ✅2015 3  臺中市大肚區 覆蓋充足（122.40%），計算。
# ✅2015 3  臺中市大里區 覆蓋充足（201.60%），計算。
# ✅2015 3  臺中市大雅區 覆蓋充足（142.76%），計算。
# ✅2015 3  臺中市太平區 覆蓋充足（77.74%），計算。
# ✅2015 3  臺中市新社區 覆蓋充足（71.36%），計算。
# ✅2015 3  臺中市東勢區 覆蓋充足（76.07%），計算。
# ✅2015 3  臺中市東區 覆蓋充足（173.74%），計算。
# ✅2015 3  臺中市梧棲區 覆蓋充足（106.42%），計算。
# ✅2015 3  臺中市沙鹿區 覆蓋充足（116.50%），計算。
# ✅2015 3  臺中市清水區 覆蓋充足（131.26%），計算。
# ✅2015 3  臺中市潭子區 覆蓋充足（90.67%），計算。
# ✅2015 3  臺中市烏日區 覆蓋充足（83.07%），計算。
# ✅2015 3  臺中市石岡區 覆蓋充足（65.77%），計算。
# ✅2015 3  臺中市神岡區 覆蓋充足（96.44%），計算。
# ✅2015 3  臺中市西區 覆蓋充足（184.52%），計算。
# ✅2015 3  臺中市西屯區 覆蓋充足（117.31%），計算。
# ✅2015 3  臺中市豐原區 覆蓋充足（112.61%），計算。
# ✅2015 3  臺中市霧峰區 覆蓋充足（97.40%），計算。
# ✅2015 3  臺中市龍井區 覆蓋充足（90.10%），計算。
# ✅2015 3  臺北市中山區 覆蓋充足（83.44%），計算。
# ✅2015 3  臺北市中正區 覆蓋充足（157.67%），計算。
# ✅2015 3  臺北市信義區 覆蓋充足（104.09%），計算。
# ✅2015 3  臺北市內湖區 覆蓋充足（73.33%），計算。
# ✅2015 3  臺北市北投區 覆蓋充足（121.74%），計算。
# ✅2015 3  臺北市南港區 覆蓋充足（106.73%），計算。
# ✅2015 3  臺北市士林區 覆蓋充足（113.33%），計算。
# ✅2015 3  臺北市文山區 覆蓋充足（149.95%），計算。
# ✅2015 3  臺北市松山區 覆蓋充足（135.30%），計算。
# ✅2015 3  臺北市萬華區 覆蓋充足（156.89%），計算。
# ✅2015 3  臺南市七股區 覆蓋充足（115.03%），計算。
# ✅2015 3  臺南市下營區 覆蓋充足（104.82%），計算。
# ✅2015 3  臺南市中西區 覆蓋充足（183.81%），計算。
# ✅2015 3  臺南市仁德區 覆蓋充足（139.38%），計算。
# ✅2015 3  臺南市佳里區 覆蓋充足（119.79%），計算。
# ✅2015 3  臺南市六甲區 覆蓋充足（87.67%），計算。
# ✅2015 3  臺南市北區 覆蓋充足（119.11%），計算。
# ✅2015 3  臺南市北門區 覆蓋充足（71.88%），計算。
# ✅2015 3  臺南市南化區 覆蓋充足（102.52%），計算。
# ✅2015 3  臺南市南區 覆蓋充足（83.80%），計算。
# ✅2015 3  臺南市善化區 覆蓋充足（131.49%），計算。
# ✅2015 3  臺南市大內區 覆蓋充足（98.88%），計算。
# ✅2015 3  臺南市學甲區 覆蓋充足（128.97%），計算。
# ✅2015 3  臺南市安南區 覆蓋充足（100.09%），計算。
# ✅2015 3  臺南市安定區 覆蓋充足（110.29%），計算。
# ✅2015 3  臺南市官田區 覆蓋充足（129.65%），計算。
# ✅2015 3  臺南市將軍區 覆蓋充足（122.57%），計算。
# ✅2015 3  臺南市山上區 覆蓋充足（84.78%），計算。
# ✅2015 3  臺南市左鎮區 覆蓋充足（112.64%），計算。
# ✅2015 3  臺南市後壁區 覆蓋充足（113.24%），計算。
# ✅2015 3  臺南市新化區 覆蓋充足（75.64%），計算。
# ✅2015 3  臺南市新市區 覆蓋充足（139.36%），計算。
# ✅2015 3  臺南市新營區 覆蓋充足（91.03%），計算。
# ✅2015 3  臺南市東區 覆蓋充足（90.83%），計算。
# ✅2015 3  臺南市東山區 覆蓋充足（94.44%），計算。
# ✅2015 3  臺南市柳營區 覆蓋充足（133.06%），計算。
# ✅2015 3  臺南市楠西區 覆蓋充足（118.20%），計算。
# ✅2015 3  臺南市歸仁區 覆蓋充足（106.58%），計算。
# ✅2015 3  臺南市永康區 覆蓋充足（114.73%），計算。
# ✅2015 3  臺南市玉井區 覆蓋充足（109.34%），計算。
# ✅2015 3  臺南市白河區 覆蓋充足（118.75%），計算。
# ✅2015 3  臺南市西港區 覆蓋充足（69.87%），計算。
# ✅2015 3  臺南市關廟區 覆蓋充足（109.40%），計算。
# ✅2015 3  臺南市鹽水區 覆蓋充足（113.55%），計算。
# ✅2015 3  臺南市麻豆區 覆蓋充足（85.36%），計算。
# ✅2015 3  臺南市龍崎區 覆蓋充足（112.77%），計算。
# ✅2015 3  臺東縣卑南鄉 覆蓋充足（60.54%），計算。
# ✅2015 3  臺東縣大武鄉 覆蓋充足（92.74%），計算。
# ✅2015 3  臺東縣太麻里鄉 覆蓋充足（90.54%），計算。
# ⚠️2015 3 臺東縣延平鄉 覆蓋不足（17.06%），略過。
# ✅2015 3  臺東縣成功鎮 覆蓋充足（80.06%），計算。
# ✅2015 3  臺東縣東河鄉 覆蓋充足（92.00%），計算。
# ✅2015 3  臺東縣池上鄉 覆蓋充足（103.50%），計算。
# ⚠️2015 3 臺東縣海端鄉 覆蓋不足（7.87%），略過。
# ✅2015 3  臺東縣綠島鄉 覆蓋充足（164.40%），計算。
# ✅2015 3  臺東縣臺東市 覆蓋充足（114.02%），計算。
# ✅2015 3  臺東縣蘭嶼鄉 覆蓋充足（123.88%），計算。
# ✅2015 3  臺東縣達仁鄉 覆蓋充足（72.97%），計算。
# ⚠️2015 3 臺東縣金峰鄉 覆蓋不足（33.25%），略過。
# ✅2015 3  臺東縣長濱鄉 覆蓋充足（93.05%），計算。
# ✅2015 3  臺東縣關山鎮 覆蓋充足（97.07%），計算。
# ✅2015 3  臺東縣鹿野鄉 覆蓋充足（88.13%），計算。
# ✅2015 3  花蓮縣光復鄉 覆蓋充足（105.96%），計算。
# ⚠️2015 3 花蓮縣卓溪鄉 覆蓋不足（14.57%），略過。
# ✅2015 3  花蓮縣吉安鄉 覆蓋充足（130.35%），計算。
# ✅2015 3  花蓮縣壽豐鄉 覆蓋充足（101.75%），計算。
# ✅2015 3  花蓮縣富里鄉 覆蓋充足（81.76%），計算。
# ✅2015 3  花蓮縣新城鄉 覆蓋充足（80.40%），計算。
# ✅2015 3  花蓮縣玉里鎮 覆蓋充足（122.08%），計算。
# ✅2015 3  花蓮縣瑞穗鄉 覆蓋充足（98.56%），計算。
# ⚠️2015 3 花蓮縣秀林鄉 覆蓋不足（18.78%），略過。
# ⚠️2015 3 花蓮縣花蓮市 覆蓋不足（37.85%），略過。
# ⚠️2015 3 花蓮縣萬榮鄉 覆蓋不足（17.77%），略過。
# ✅2015 3  花蓮縣豐濱鄉 覆蓋充足（124.71%），計算。
# ✅2015 3  花蓮縣鳳林鎮 覆蓋充足（98.30%），計算。
# ✅2015 3  苗栗縣三灣鄉 覆蓋充足（86.45%），計算。
# ✅2015 3  苗栗縣三義鄉 覆蓋充足（103.79%），計算。
# ✅2015 3  苗栗縣公館鄉 覆蓋充足（114.38%），計算。
# ✅2015 3  苗栗縣卓蘭鎮 覆蓋充足（75.66%），計算。
# ✅2015 3  苗栗縣南庄鄉 覆蓋充足（57.84%），計算。
# ⚠️2015 3 苗栗縣大湖鄉 覆蓋不足（38.64%），略過。
# ✅2015 3  苗栗縣後龍鎮 覆蓋充足（122.28%），計算。
# ⚠️2015 3 苗栗縣泰安鄉 覆蓋不足（1.94%），略過。
# ✅2015 3  苗栗縣獅潭鄉 覆蓋充足（103.29%），計算。
# ✅2015 3  苗栗縣竹南鎮 覆蓋充足（112.57%），計算。
# ✅2015 3  苗栗縣苑裡鎮 覆蓋充足（84.18%），計算。
# ✅2015 3  苗栗縣苗栗市 覆蓋充足（93.33%），計算。
# ✅2015 3  苗栗縣西湖鄉 覆蓋充足（114.46%），計算。
# ✅2015 3  苗栗縣通霄鎮 覆蓋充足（113.23%），計算。
# ✅2015 3  苗栗縣造橋鄉 覆蓋充足（121.21%），計算。
# ✅2015 3  苗栗縣銅鑼鄉 覆蓋充足（120.05%），計算。
# ✅2015 3  苗栗縣頭份市 覆蓋充足（154.94%），計算。
# ✅2015 3  苗栗縣頭屋鄉 覆蓋充足（90.85%），計算。
# ✅2015 3  雲林縣二崙鄉 覆蓋充足（96.36%），計算。
# ✅2015 3  雲林縣元長鄉 覆蓋充足（81.16%），計算。
# ✅2015 3  雲林縣北港鎮 覆蓋充足（84.40%），計算。
# ✅2015 3  雲林縣口湖鄉 覆蓋充足（106.49%），計算。
# ✅2015 3  雲林縣古坑鄉 覆蓋充足（91.63%），計算。
# ✅2015 3  雲林縣四湖鄉 覆蓋充足（113.61%），計算。
# ✅2015 3  雲林縣土庫鎮 覆蓋充足（121.79%），計算。
# ✅2015 3  雲林縣大埤鄉 覆蓋充足（79.32%），計算。
# ✅2015 3  雲林縣崙背鄉 覆蓋充足（61.51%），計算。
# ✅2015 3  雲林縣斗六市 覆蓋充足（127.62%），計算。
# ✅2015 3  雲林縣斗南鎮 覆蓋充足（121.28%），計算。
# ✅2015 3  雲林縣東勢鄉 覆蓋充足（126.06%），計算。
# ✅2015 3  雲林縣林內鄉 覆蓋充足（89.88%），計算。
# ✅2015 3  雲林縣水林鄉 覆蓋充足（128.70%），計算。
# ✅2015 3  雲林縣臺西鄉 覆蓋充足（101.19%），計算。
# ✅2015 3  雲林縣莿桐鄉 覆蓋充足（102.50%），計算。
# ✅2015 3  雲林縣虎尾鎮 覆蓋充足（119.96%），計算。
# ✅2015 3  雲林縣褒忠鄉 覆蓋充足（98.56%），計算。
# ✅2015 3  雲林縣西螺鎮 覆蓋充足（93.61%），計算。
# ✅2015 3  雲林縣麥寮鄉 覆蓋充足（112.12%），計算。
# ✅2015 3  高雄市三民區 覆蓋充足（69.01%），計算。
# ✅2015 3  高雄市仁武區 覆蓋充足（92.95%），計算。
# ✅2015 3  高雄市內門區 覆蓋充足（98.86%），計算。
# ✅2015 3  高雄市六龜區 覆蓋充足（84.46%），計算。
# ✅2015 3  高雄市前金區 覆蓋充足（596.19%），計算。
# ✅2015 3  高雄市前鎮區 覆蓋充足（165.67%），計算。
# ✅2015 3  高雄市大寮區 覆蓋充足（117.00%），計算。
# ✅2015 3  高雄市大樹區 覆蓋充足（121.51%），計算。
# ✅2015 3  高雄市大社區 覆蓋充足（92.44%），計算。
# ✅2015 3  高雄市小港區 覆蓋充足（108.63%），計算。
# ✅2015 3  高雄市岡山區 覆蓋充足（117.85%），計算。
# ✅2015 3  高雄市左營區 覆蓋充足（103.53%），計算。
# ✅2015 3  高雄市彌陀區 覆蓋充足（79.55%），計算。
# ✅2015 3  高雄市旗山區 覆蓋充足（136.24%），計算。
# ✅2015 3  高雄市旗津區 覆蓋充足（80.64%），計算。
# ✅2015 3  高雄市杉林區 覆蓋充足（112.98%），計算。
# ✅2015 3  高雄市林園區 覆蓋充足（98.20%），計算。
# ⚠️2015 3 高雄市桃源區 覆蓋不足（2.40%），略過。
# ✅2015 3  高雄市梓官區 覆蓋充足（98.91%），計算。
# ✅2015 3  高雄市楠梓區 覆蓋充足（165.36%），計算。
# ⚠️2015 3 高雄市橋頭區 覆蓋不足（48.07%），略過。
# ✅2015 3  高雄市永安區 覆蓋充足（131.11%），計算。
# ✅2015 3  高雄市湖內區 覆蓋充足（107.74%），計算。
# ✅2015 3  高雄市燕巢區 覆蓋充足（120.12%），計算。
# ✅2015 3  高雄市田寮區 覆蓋充足（103.84%），計算。
# ✅2015 3  高雄市甲仙區 覆蓋充足（66.19%），計算。
# ✅2015 3  高雄市美濃區 覆蓋充足（98.82%），計算。
# ✅2015 3  高雄市苓雅區 覆蓋充足（139.82%），計算。
# ⚠️2015 3 高雄市茂林區 覆蓋不足（9.70%），略過。
# ✅2015 3  高雄市茄萣區 覆蓋充足（68.70%），計算。
# ✅2015 3  高雄市路竹區 覆蓋充足（115.73%），計算。
# ✅2015 3  高雄市阿蓮區 覆蓋充足（67.10%），計算。
# ✅2015 3  高雄市鳥松區 覆蓋充足（142.28%），計算。
# ✅2015 3  高雄市鳳山區 覆蓋充足（83.99%），計算。
# ✅2015 3  高雄市鼓山區 覆蓋充足（158.89%），計算。
# ✅ 完成：NO 2015 week 3
# ✅2015 4  南投縣中寮鄉 覆蓋充足（97.70%），計算。
# ⚠️2015 4 南投縣仁愛鄉 覆蓋不足（5.76%），略過。
# ⚠️2015 4 南投縣信義鄉 覆蓋不足（1.65%），略過。
# ✅2015 4  南投縣南投市 覆蓋充足（114.11%），計算。
# ✅2015 4  南投縣名間鄉 覆蓋充足（118.21%），計算。
# ✅2015 4  南投縣國姓鄉 覆蓋充足（68.26%），計算。
# ✅2015 4  南投縣埔里鎮 覆蓋充足（95.67%），計算。
# ✅2015 4  南投縣水里鄉 覆蓋充足（62.89%），計算。
# ✅2015 4  南投縣竹山鎮 覆蓋充足（63.42%），計算。
# ✅2015 4  南投縣草屯鎮 覆蓋充足（90.14%），計算。
# ✅2015 4  南投縣集集鎮 覆蓋充足（88.45%），計算。
# ✅2015 4  南投縣魚池鄉 覆蓋充足（65.93%），計算。
# ✅2015 4  南投縣鹿谷鄉 覆蓋充足（81.95%），計算。
# ✅2015 4  嘉義市東區 覆蓋充足（78.49%），計算。
# ✅2015 4  嘉義市西區 覆蓋充足（156.84%），計算。
# ✅2015 4  嘉義縣中埔鄉 覆蓋充足（90.00%），計算。
# ✅2015 4  嘉義縣六腳鄉 覆蓋充足（112.78%），計算。
# ✅2015 4  嘉義縣大埔鄉 覆蓋充足（100.81%），計算。
# ✅2015 4  嘉義縣大林鎮 覆蓋充足（108.78%），計算。
# ✅2015 4  嘉義縣太保市 覆蓋充足（123.39%），計算。
# ✅2015 4  嘉義縣布袋鎮 覆蓋充足（88.91%），計算。
# ✅2015 4  嘉義縣新港鄉 覆蓋充足（106.18%），計算。
# ✅2015 4  嘉義縣朴子市 覆蓋充足（93.78%），計算。
# ✅2015 4  嘉義縣東石鄉 覆蓋充足（100.02%），計算。
# ✅2015 4  嘉義縣梅山鄉 覆蓋充足（58.82%），計算。
# ✅2015 4  嘉義縣民雄鄉 覆蓋充足（96.59%），計算。
# ✅2015 4  嘉義縣水上鄉 覆蓋充足（83.60%），計算。
# ✅2015 4  嘉義縣溪口鄉 覆蓋充足（144.53%），計算。
# ✅2015 4  嘉義縣番路鄉 覆蓋充足（83.37%），計算。
# ✅2015 4  嘉義縣竹崎鄉 覆蓋充足（59.75%），計算。
# ✅2015 4  嘉義縣義竹鄉 覆蓋充足（133.76%），計算。
# ✅2015 4  嘉義縣鹿草鄉 覆蓋充足（128.87%），計算。
# ✅2015 4  基隆市七堵區 覆蓋充足（125.04%），計算。
# ✅2015 4  基隆市仁愛區 覆蓋充足（257.15%），計算。
# ✅2015 4  基隆市信義區 覆蓋充足（110.51%），計算。
# ✅2015 4  基隆市安樂區 覆蓋充足（126.24%），計算。
# ✅2015 4  基隆市暖暖區 覆蓋充足（102.34%），計算。
# ✅2015 4  宜蘭縣三星鄉 覆蓋充足（119.74%），計算。
# ✅2015 4  宜蘭縣五結鄉 覆蓋充足（116.30%），計算。
# ✅2015 4  宜蘭縣冬山鄉 覆蓋充足（124.73%），計算。
# ⚠️2015 4 宜蘭縣南澳鄉 覆蓋不足（37.81%），略過。
# ✅2015 4  宜蘭縣員山鄉 覆蓋充足（82.76%），計算。
# ✅2015 4  宜蘭縣壯圍鄉 覆蓋充足（89.08%），計算。
# ⚠️2015 4 宜蘭縣大同鄉 覆蓋不足（19.78%），略過。
# ✅2015 4  宜蘭縣宜蘭市 覆蓋充足（153.97%），計算。
# ✅2015 4  宜蘭縣礁溪鄉 覆蓋充足（93.07%），計算。
# ✅2015 4  宜蘭縣蘇澳鎮 覆蓋充足（130.78%），計算。
# ✅2015 4  宜蘭縣頭城鎮 覆蓋充足（80.00%），計算。
# ✅2015 4  屏東縣三地門鄉 覆蓋充足（81.91%），計算。
# ✅2015 4  屏東縣九如鄉 覆蓋充足（108.69%），計算。
# ✅2015 4  屏東縣佳冬鄉 覆蓋充足（108.71%），計算。
# ✅2015 4  屏東縣來義鄉 覆蓋充足（57.75%），計算。
# ✅2015 4  屏東縣內埔鄉 覆蓋充足（121.47%），計算。
# ✅2015 4  屏東縣南州鄉 覆蓋充足（62.32%），計算。
# ✅2015 4  屏東縣屏東市 覆蓋充足（124.15%），計算。
# ✅2015 4  屏東縣崁頂鄉 覆蓋充足（138.82%），計算。
# ✅2015 4  屏東縣恆春鎮 覆蓋充足（99.71%），計算。
# ✅2015 4  屏東縣新園鄉 覆蓋充足（77.39%），計算。
# ✅2015 4  屏東縣新埤鄉 覆蓋充足（144.47%），計算。
# ✅2015 4  屏東縣春日鄉 覆蓋充足（82.84%），計算。
# ✅2015 4  屏東縣東港鎮 覆蓋充足（114.01%），計算。
# ✅2015 4  屏東縣枋寮鄉 覆蓋充足（96.78%），計算。
# ✅2015 4  屏東縣枋山鄉 覆蓋充足（259.16%），計算。
# ✅2015 4  屏東縣林邊鄉 覆蓋充足（137.18%），計算。
# ⚠️2015 4 屏東縣泰武鄉 覆蓋不足（47.19%），略過。
# ✅2015 4  屏東縣滿州鄉 覆蓋充足（117.85%），計算。
# ✅2015 4  屏東縣潮州鎮 覆蓋充足（82.63%），計算。
# ✅2015 4  屏東縣牡丹鄉 覆蓋充足（107.42%），計算。
# ✅2015 4  屏東縣獅子鄉 覆蓋充足（85.98%），計算。
# ✅2015 4  屏東縣琉球鄉 覆蓋充足（170.86%），計算。
# ✅2015 4  屏東縣瑪家鄉 覆蓋充足（94.96%），計算。
# ✅2015 4  屏東縣竹田鄉 覆蓋充足（118.56%），計算。
# ✅2015 4  屏東縣萬丹鄉 覆蓋充足（118.56%），計算。
# ✅2015 4  屏東縣萬巒鄉 覆蓋充足（57.76%），計算。
# ✅2015 4  屏東縣車城鄉 覆蓋充足（117.82%），計算。
# ✅2015 4  屏東縣里港鄉 覆蓋充足（100.82%），計算。
# ✅2015 4  屏東縣長治鄉 覆蓋充足（51.16%），計算。
# ⚠️2015 4 屏東縣霧臺鄉 覆蓋不足（3.84%），略過。
# ✅2015 4  屏東縣高樹鄉 覆蓋充足（87.02%），計算。
# ✅2015 4  屏東縣鹽埔鄉 覆蓋充足（118.79%），計算。
# ✅2015 4  屏東縣麟洛鄉 覆蓋充足（168.51%），計算。
# ✅2015 4  彰化縣二林鎮 覆蓋充足（101.64%），計算。
# ✅2015 4  彰化縣二水鄉 覆蓋充足（131.73%），計算。
# ✅2015 4  彰化縣伸港鄉 覆蓋充足（99.57%），計算。
# ✅2015 4  彰化縣北斗鎮 覆蓋充足（118.61%），計算。
# ✅2015 4  彰化縣和美鎮 覆蓋充足（122.71%），計算。
# ✅2015 4  彰化縣員林市 覆蓋充足（59.44%），計算。
# ✅2015 4  彰化縣埔心鄉 覆蓋充足（55.82%），計算。
# ✅2015 4  彰化縣埔鹽鄉 覆蓋充足（119.96%），計算。
# ✅2015 4  彰化縣埤頭鄉 覆蓋充足（137.86%），計算。
# ✅2015 4  彰化縣大城鄉 覆蓋充足（110.56%），計算。
# ✅2015 4  彰化縣大村鄉 覆蓋充足（153.86%），計算。
# ✅2015 4  彰化縣彰化市 覆蓋充足（71.25%），計算。
# ✅2015 4  彰化縣永靖鄉 覆蓋充足（115.44%），計算。
# ✅2015 4  彰化縣溪州鄉 覆蓋充足（118.39%），計算。
# ✅2015 4  彰化縣溪湖鎮 覆蓋充足（150.99%），計算。
# ✅2015 4  彰化縣田中鎮 覆蓋充足（68.00%），計算。
# ✅2015 4  彰化縣田尾鄉 覆蓋充足（94.82%），計算。
# ✅2015 4  彰化縣社頭鄉 覆蓋充足（130.46%），計算。
# ✅2015 4  彰化縣福興鄉 覆蓋充足（161.04%），計算。
# ✅2015 4  彰化縣秀水鄉 覆蓋充足（80.55%），計算。
# ✅2015 4  彰化縣竹塘鄉 覆蓋充足（111.85%），計算。
# ✅2015 4  彰化縣線西鄉 覆蓋充足（113.73%），計算。
# ✅2015 4  彰化縣芬園鄉 覆蓋充足（152.98%），計算。
# ✅2015 4  彰化縣花壇鄉 覆蓋充足（130.30%），計算。
# ✅2015 4  彰化縣芳苑鄉 覆蓋充足（104.76%），計算。
# ✅2015 4  彰化縣鹿港鎮 覆蓋充足（84.69%），計算。
# ✅2015 4  新北市三峽區 覆蓋充足（86.50%），計算。
# ✅2015 4  新北市三芝區 覆蓋充足（86.75%），計算。
# ✅2015 4  新北市三重區 覆蓋充足（65.14%），計算。
# ✅2015 4  新北市中和區 覆蓋充足（120.58%），計算。
# ✅2015 4  新北市五股區 覆蓋充足（102.37%），計算。
# ✅2015 4  新北市八里區 覆蓋充足（117.87%），計算。
# ✅2015 4  新北市土城區 覆蓋充足（117.38%），計算。
# ✅2015 4  新北市坪林區 覆蓋充足（69.61%），計算。
# ✅2015 4  新北市平溪區 覆蓋充足（131.69%），計算。
# ✅2015 4  新北市新店區 覆蓋充足（96.68%），計算。
# ✅2015 4  新北市新莊區 覆蓋充足（169.91%），計算。
# ✅2015 4  新北市板橋區 覆蓋充足（110.09%），計算。
# ✅2015 4  新北市林口區 覆蓋充足（129.46%），計算。
# ✅2015 4  新北市樹林區 覆蓋充足（110.11%），計算。
# ✅2015 4  新北市永和區 覆蓋充足（190.21%），計算。
# ✅2015 4  新北市汐止區 覆蓋充足（114.21%），計算。
# ✅2015 4  新北市淡水區 覆蓋充足（96.16%），計算。
# ✅2015 4  新北市深坑區 覆蓋充足（111.86%），計算。
# ⚠️2015 4 新北市烏來區 覆蓋不足（31.61%），略過。
# ✅2015 4  新北市瑞芳區 覆蓋充足（97.31%），計算。
# ✅2015 4  新北市石碇區 覆蓋充足（107.30%），計算。
# ✅2015 4  新北市石門區 覆蓋充足（110.52%），計算。
# ✅2015 4  新北市萬里區 覆蓋充足（110.56%），計算。
# ✅2015 4  新北市蘆洲區 覆蓋充足（151.81%），計算。
# ✅2015 4  新北市貢寮區 覆蓋充足（115.08%），計算。
# ✅2015 4  新北市金山區 覆蓋充足（98.16%），計算。
# ✅2015 4  新北市雙溪區 覆蓋充足（104.53%），計算。
# ✅2015 4  新北市鶯歌區 覆蓋充足（107.27%），計算。
# ✅2015 4  新竹市北區 覆蓋充足（99.36%），計算。
# ✅2015 4  新竹市東區 覆蓋充足（68.33%），計算。
# ✅2015 4  新竹市香山區 覆蓋充足（87.97%），計算。
# ⚠️2015 4 新竹縣五峰鄉 覆蓋不足（22.31%），略過。
# ✅2015 4  新竹縣北埔鄉 覆蓋充足（87.72%），計算。
# ✅2015 4  新竹縣寶山鄉 覆蓋充足（109.37%），計算。
# ⚠️2015 4 新竹縣尖石鄉 覆蓋不足（11.20%），略過。
# ✅2015 4  新竹縣峨眉鄉 覆蓋充足（125.87%），計算。
# ✅2015 4  新竹縣新埔鎮 覆蓋充足（97.34%），計算。
# ✅2015 4  新竹縣新豐鄉 覆蓋充足（117.40%），計算。
# ✅2015 4  新竹縣橫山鄉 覆蓋充足（107.90%），計算。
# ✅2015 4  新竹縣湖口鄉 覆蓋充足（80.74%），計算。
# ✅2015 4  新竹縣竹北市 覆蓋充足（116.31%），計算。
# ✅2015 4  新竹縣竹東鎮 覆蓋充足（131.36%），計算。
# ✅2015 4  新竹縣芎林鄉 覆蓋充足（117.35%），計算。
# ✅2015 4  新竹縣關西鎮 覆蓋充足（121.63%），計算。
# ✅2015 4  桃園市中壢區 覆蓋充足（92.35%），計算。
# ✅2015 4  桃園市八德區 覆蓋充足（69.32%），計算。
# ✅2015 4  桃園市大園區 覆蓋充足（104.01%），計算。
# ✅2015 4  桃園市大溪區 覆蓋充足（122.59%），計算。
# ✅2015 4  桃園市平鎮區 覆蓋充足（134.78%），計算。
# ⚠️2015 4 桃園市復興區 覆蓋不足（24.34%），略過。
# ✅2015 4  桃園市新屋區 覆蓋充足（91.84%），計算。
# ✅2015 4  桃園市桃園區 覆蓋充足（136.31%），計算。
# ✅2015 4  桃園市楊梅區 覆蓋充足（117.57%），計算。
# ✅2015 4  桃園市蘆竹區 覆蓋充足（109.58%），計算。
# ✅2015 4  桃園市觀音區 覆蓋充足（121.68%），計算。
# ✅2015 4  桃園市龍潭區 覆蓋充足（123.40%），計算。
# ✅2015 4  桃園市龜山區 覆蓋充足（81.98%），計算。
# ✅2015 4  臺中市北屯區 覆蓋充足（113.97%），計算。
# ✅2015 4  臺中市南屯區 覆蓋充足（115.59%），計算。
# ✅2015 4  臺中市后里區 覆蓋充足（122.88%），計算。
# ✅2015 4  臺中市外埔區 覆蓋充足（139.16%），計算。
# ✅2015 4  臺中市大安區 覆蓋充足（98.92%），計算。
# ✅2015 4  臺中市大甲區 覆蓋充足（98.68%），計算。
# ✅2015 4  臺中市大肚區 覆蓋充足（122.40%），計算。
# ✅2015 4  臺中市大里區 覆蓋充足（201.60%），計算。
# ✅2015 4  臺中市大雅區 覆蓋充足（142.76%），計算。
# ✅2015 4  臺中市太平區 覆蓋充足（77.74%），計算。
# ✅2015 4  臺中市新社區 覆蓋充足（71.36%），計算。
# ✅2015 4  臺中市東勢區 覆蓋充足（76.07%），計算。
# ✅2015 4  臺中市東區 覆蓋充足（173.74%），計算。
# ✅2015 4  臺中市梧棲區 覆蓋充足（106.42%），計算。
# ✅2015 4  臺中市沙鹿區 覆蓋充足（116.50%），計算。
# ✅2015 4  臺中市清水區 覆蓋充足（131.26%），計算。
# ✅2015 4  臺中市潭子區 覆蓋充足（90.67%），計算。
# ✅2015 4  臺中市烏日區 覆蓋充足（83.07%），計算。
# ✅2015 4  臺中市石岡區 覆蓋充足（65.77%），計算。
# ✅2015 4  臺中市神岡區 覆蓋充足（96.44%），計算。
# ✅2015 4  臺中市西區 覆蓋充足（184.52%），計算。
# ✅2015 4  臺中市西屯區 覆蓋充足（117.31%），計算。
# ✅2015 4  臺中市豐原區 覆蓋充足（112.61%），計算。
# ✅2015 4  臺中市霧峰區 覆蓋充足（97.40%），計算。
# ✅2015 4  臺中市龍井區 覆蓋充足（90.10%），計算。
# ✅2015 4  臺北市中山區 覆蓋充足（83.44%），計算。
# ✅2015 4  臺北市中正區 覆蓋充足（157.67%），計算。
# ✅2015 4  臺北市信義區 覆蓋充足（104.09%），計算。
# ✅2015 4  臺北市內湖區 覆蓋充足（73.33%），計算。
# ✅2015 4  臺北市北投區 覆蓋充足（121.74%），計算。
# ✅2015 4  臺北市南港區 覆蓋充足（106.73%），計算。
# ✅2015 4  臺北市士林區 覆蓋充足（113.33%），計算。
# ✅2015 4  臺北市文山區 覆蓋充足（149.95%），計算。
# ✅2015 4  臺北市松山區 覆蓋充足（135.30%），計算。
# ✅2015 4  臺北市萬華區 覆蓋充足（156.89%），計算。
# ✅2015 4  臺南市七股區 覆蓋充足（115.03%），計算。
# ✅2015 4  臺南市下營區 覆蓋充足（104.82%），計算。
# ✅2015 4  臺南市中西區 覆蓋充足（183.81%），計算。
# ✅2015 4  臺南市仁德區 覆蓋充足（139.38%），計算。
# ✅2015 4  臺南市佳里區 覆蓋充足（119.79%），計算。
# ✅2015 4  臺南市六甲區 覆蓋充足（87.67%），計算。
# ✅2015 4  臺南市北區 覆蓋充足（119.11%），計算。
# ✅2015 4  臺南市北門區 覆蓋充足（71.88%），計算。
# ✅2015 4  臺南市南化區 覆蓋充足（102.52%），計算。
# ✅2015 4  臺南市南區 覆蓋充足（83.80%），計算。
# ✅2015 4  臺南市善化區 覆蓋充足（131.49%），計算。
# ✅2015 4  臺南市大內區 覆蓋充足（98.88%），計算。
# ✅2015 4  臺南市學甲區 覆蓋充足（128.97%），計算。
# ✅2015 4  臺南市安南區 覆蓋充足（100.09%），計算。
# ✅2015 4  臺南市安定區 覆蓋充足（110.29%），計算。
# ✅2015 4  臺南市官田區 覆蓋充足（129.65%），計算。
# ✅2015 4  臺南市將軍區 覆蓋充足（122.57%），計算。
# ✅2015 4  臺南市山上區 覆蓋充足（84.78%），計算。
# ✅2015 4  臺南市左鎮區 覆蓋充足（112.64%），計算。
# ✅2015 4  臺南市後壁區 覆蓋充足（113.24%），計算。
# ✅2015 4  臺南市新化區 覆蓋充足（75.64%），計算。
# ✅2015 4  臺南市新市區 覆蓋充足（139.36%），計算。
# ✅2015 4  臺南市新營區 覆蓋充足（91.03%），計算。
# ✅2015 4  臺南市東區 覆蓋充足（90.83%），計算。
# ✅2015 4  臺南市東山區 覆蓋充足（94.44%），計算。
# ✅2015 4  臺南市柳營區 覆蓋充足（133.06%），計算。
# ✅2015 4  臺南市楠西區 覆蓋充足（118.20%），計算。
# ✅2015 4  臺南市歸仁區 覆蓋充足（106.58%），計算。
# ✅2015 4  臺南市永康區 覆蓋充足（114.73%），計算。
# ✅2015 4  臺南市玉井區 覆蓋充足（109.34%），計算。
# ✅2015 4  臺南市白河區 覆蓋充足（118.75%），計算。
# ✅2015 4  臺南市西港區 覆蓋充足（69.87%），計算。
# ✅2015 4  臺南市關廟區 覆蓋充足（109.40%），計算。
# ✅2015 4  臺南市鹽水區 覆蓋充足（113.55%），計算。
# ✅2015 4  臺南市麻豆區 覆蓋充足（85.36%），計算。
# ✅2015 4  臺南市龍崎區 覆蓋充足（112.77%），計算。
# ✅2015 4  臺東縣卑南鄉 覆蓋充足（60.54%），計算。
# ✅2015 4  臺東縣大武鄉 覆蓋充足（92.74%），計算。
# ✅2015 4  臺東縣太麻里鄉 覆蓋充足（90.54%），計算。
# ⚠️2015 4 臺東縣延平鄉 覆蓋不足（17.06%），略過。
# ✅2015 4  臺東縣成功鎮 覆蓋充足（80.06%），計算。
# ✅2015 4  臺東縣東河鄉 覆蓋充足（92.00%），計算。
# ✅2015 4  臺東縣池上鄉 覆蓋充足（103.50%），計算。
# ⚠️2015 4 臺東縣海端鄉 覆蓋不足（7.87%），略過。
# ✅2015 4  臺東縣綠島鄉 覆蓋充足（164.40%），計算。
# ✅2015 4  臺東縣臺東市 覆蓋充足（114.02%），計算。
# ✅2015 4  臺東縣蘭嶼鄉 覆蓋充足（123.88%），計算。
# ✅2015 4  臺東縣達仁鄉 覆蓋充足（72.97%），計算。
# ⚠️2015 4 臺東縣金峰鄉 覆蓋不足（33.25%），略過。
# ✅2015 4  臺東縣長濱鄉 覆蓋充足（93.05%），計算。
# ✅2015 4  臺東縣關山鎮 覆蓋充足（97.07%），計算。
# ✅2015 4  臺東縣鹿野鄉 覆蓋充足（88.13%），計算。
# ✅2015 4  花蓮縣光復鄉 覆蓋充足（105.96%），計算。
# ⚠️2015 4 花蓮縣卓溪鄉 覆蓋不足（14.57%），略過。
# ✅2015 4  花蓮縣吉安鄉 覆蓋充足（130.35%），計算。
# ✅2015 4  花蓮縣壽豐鄉 覆蓋充足（101.75%），計算。
# ✅2015 4  花蓮縣富里鄉 覆蓋充足（81.76%），計算。
# ✅2015 4  花蓮縣新城鄉 覆蓋充足（80.40%），計算。
# ✅2015 4  花蓮縣玉里鎮 覆蓋充足（122.08%），計算。
# ✅2015 4  花蓮縣瑞穗鄉 覆蓋充足（98.56%），計算。
# ⚠️2015 4 花蓮縣秀林鄉 覆蓋不足（18.78%），略過。
# ⚠️2015 4 花蓮縣花蓮市 覆蓋不足（37.85%），略過。
# ⚠️2015 4 花蓮縣萬榮鄉 覆蓋不足（17.77%），略過。
# ✅2015 4  花蓮縣豐濱鄉 覆蓋充足（124.71%），計算。
# ✅2015 4  花蓮縣鳳林鎮 覆蓋充足（98.30%），計算。
# ✅2015 4  苗栗縣三灣鄉 覆蓋充足（86.45%），計算。
# ✅2015 4  苗栗縣三義鄉 覆蓋充足（103.79%），計算。
# ✅2015 4  苗栗縣公館鄉 覆蓋充足（114.38%），計算。
# ✅2015 4  苗栗縣卓蘭鎮 覆蓋充足（75.66%），計算。
# ✅2015 4  苗栗縣南庄鄉 覆蓋充足（57.84%），計算。
# ⚠️2015 4 苗栗縣大湖鄉 覆蓋不足（38.64%），略過。
# ✅2015 4  苗栗縣後龍鎮 覆蓋充足（122.28%），計算。
# ⚠️2015 4 苗栗縣泰安鄉 覆蓋不足（1.94%），略過。
# ✅2015 4  苗栗縣獅潭鄉 覆蓋充足（103.29%），計算。
# ✅2015 4  苗栗縣竹南鎮 覆蓋充足（112.57%），計算。
# ✅2015 4  苗栗縣苑裡鎮 覆蓋充足（84.18%），計算。
# ✅2015 4  苗栗縣苗栗市 覆蓋充足（93.33%），計算。
# ✅2015 4  苗栗縣西湖鄉 覆蓋充足（114.46%），計算。
# ✅2015 4  苗栗縣通霄鎮 覆蓋充足（113.23%），計算。
# ✅2015 4  苗栗縣造橋鄉 覆蓋充足（121.21%），計算。
# ✅2015 4  苗栗縣銅鑼鄉 覆蓋充足（120.05%），計算。
# ✅2015 4  苗栗縣頭份市 覆蓋充足（154.94%），計算。
# ✅2015 4  苗栗縣頭屋鄉 覆蓋充足（90.85%），計算。
# ✅2015 4  雲林縣二崙鄉 覆蓋充足（96.36%），計算。
# ✅2015 4  雲林縣元長鄉 覆蓋充足（81.16%），計算。
# ✅2015 4  雲林縣北港鎮 覆蓋充足（84.40%），計算。
# ✅2015 4  雲林縣口湖鄉 覆蓋充足（106.49%），計算。
# ✅2015 4  雲林縣古坑鄉 覆蓋充足（91.63%），計算。
# ✅2015 4  雲林縣四湖鄉 覆蓋充足（113.61%），計算。
# ✅2015 4  雲林縣土庫鎮 覆蓋充足（121.79%），計算。
# ✅2015 4  雲林縣大埤鄉 覆蓋充足（79.32%），計算。
# ✅2015 4  雲林縣崙背鄉 覆蓋充足（61.51%），計算。
# ✅2015 4  雲林縣斗六市 覆蓋充足（127.62%），計算。
# ✅2015 4  雲林縣斗南鎮 覆蓋充足（121.28%），計算。
# ✅2015 4  雲林縣東勢鄉 覆蓋充足（126.06%），計算。
# ✅2015 4  雲林縣林內鄉 覆蓋充足（89.88%），計算。
# ✅2015 4  雲林縣水林鄉 覆蓋充足（128.70%），計算。
# ✅2015 4  雲林縣臺西鄉 覆蓋充足（101.19%），計算。
# ✅2015 4  雲林縣莿桐鄉 覆蓋充足（102.50%），計算。
# ✅2015 4  雲林縣虎尾鎮 覆蓋充足（119.96%），計算。
# ✅2015 4  雲林縣褒忠鄉 覆蓋充足（98.56%），計算。
# ✅2015 4  雲林縣西螺鎮 覆蓋充足（93.61%），計算。
# ✅2015 4  雲林縣麥寮鄉 覆蓋充足（112.12%），計算。
# ✅2015 4  高雄市三民區 覆蓋充足（69.01%），計算。
# ✅2015 4  高雄市仁武區 覆蓋充足（92.95%），計算。
# ✅2015 4  高雄市內門區 覆蓋充足（98.86%），計算。
# ✅2015 4  高雄市六龜區 覆蓋充足（84.46%），計算。
# ✅2015 4  高雄市前金區 覆蓋充足（596.19%），計算。
# ✅2015 4  高雄市前鎮區 覆蓋充足（165.67%），計算。
# ✅2015 4  高雄市大寮區 覆蓋充足（117.00%），計算。
# ✅2015 4  高雄市大樹區 覆蓋充足（121.51%），計算。
# ✅2015 4  高雄市大社區 覆蓋充足（92.44%），計算。
# ✅2015 4  高雄市小港區 覆蓋充足（108.63%），計算。
# ✅2015 4  高雄市岡山區 覆蓋充足（117.85%），計算。
# ✅2015 4  高雄市左營區 覆蓋充足（103.53%），計算。
# ✅2015 4  高雄市彌陀區 覆蓋充足（79.55%），計算。
# ✅2015 4  高雄市旗山區 覆蓋充足（136.24%），計算。
# ✅2015 4  高雄市旗津區 覆蓋充足（80.64%），計算。
# ✅2015 4  高雄市杉林區 覆蓋充足（112.98%），計算。
# ✅2015 4  高雄市林園區 覆蓋充足（98.20%），計算。
# ⚠️2015 4 高雄市桃源區 覆蓋不足（2.40%），略過。
# ✅2015 4  高雄市梓官區 覆蓋充足（98.91%），計算。
# ✅2015 4  高雄市楠梓區 覆蓋充足（165.36%），計算。
# ⚠️2015 4 高雄市橋頭區 覆蓋不足（48.07%），略過。
# ✅2015 4  高雄市永安區 覆蓋充足（131.11%），計算。
# ✅2015 4  高雄市湖內區 覆蓋充足（107.74%），計算。
# ✅2015 4  高雄市燕巢區 覆蓋充足（120.12%），計算。
# ✅2015 4  高雄市田寮區 覆蓋充足（103.84%），計算。
# ✅2015 4  高雄市甲仙區 覆蓋充足（66.19%），計算。
# ✅2015 4  高雄市美濃區 覆蓋充足（98.82%），計算。
# ✅2015 4  高雄市苓雅區 覆蓋充足（139.82%），計算。
# ⚠️2015 4 高雄市茂林區 覆蓋不足（9.70%），略過。
# ✅2015 4  高雄市茄萣區 覆蓋充足（68.70%），計算。
# ✅2015 4  高雄市路竹區 覆蓋充足（115.73%），計算。
# ✅2015 4  高雄市阿蓮區 覆蓋充足（67.10%），計算。
# ✅2015 4  高雄市鳥松區 覆蓋充足（142.28%），計算。
# ✅2015 4  高雄市鳳山區 覆蓋充足（83.99%），計算。
# ✅2015 4  高雄市鼓山區 覆蓋充足（158.89%），計算。
# ✅ 完成：NO 2015 week 4
# ✅2015 5  南投縣中寮鄉 覆蓋充足（97.70%），計算。
# ⚠️2015 5 南投縣仁愛鄉 覆蓋不足（5.76%），略過。
# ⚠️2015 5 南投縣信義鄉 覆蓋不足（1.65%），略過。
# ✅2015 5  南投縣南投市 覆蓋充足（114.11%），計算。
# ✅2015 5  南投縣名間鄉 覆蓋充足（118.21%），計算。
# ✅2015 5  南投縣國姓鄉 覆蓋充足（68.26%），計算。
# ✅2015 5  南投縣埔里鎮 覆蓋充足（95.67%），計算。
# ✅2015 5  南投縣水里鄉 覆蓋充足（62.89%），計算。
# ✅2015 5  南投縣竹山鎮 覆蓋充足（63.42%），計算。
# ✅2015 5  南投縣草屯鎮 覆蓋充足（90.14%），計算。
# ✅2015 5  南投縣集集鎮 覆蓋充足（88.45%），計算。
# ✅2015 5  南投縣魚池鄉 覆蓋充足（65.93%），計算。
# ✅2015 5  南投縣鹿谷鄉 覆蓋充足（81.95%），計算。
# ✅2015 5  嘉義市東區 覆蓋充足（78.49%），計算。
# ✅2015 5  嘉義市西區 覆蓋充足（156.84%），計算。
# ✅2015 5  嘉義縣中埔鄉 覆蓋充足（90.00%），計算。
# ✅2015 5  嘉義縣六腳鄉 覆蓋充足（112.78%），計算。
# ✅2015 5  嘉義縣大埔鄉 覆蓋充足（100.81%），計算。
# ✅2015 5  嘉義縣大林鎮 覆蓋充足（108.78%），計算。
# ✅2015 5  嘉義縣太保市 覆蓋充足（123.39%），計算。
# ✅2015 5  嘉義縣布袋鎮 覆蓋充足（88.91%），計算。
# ✅2015 5  嘉義縣新港鄉 覆蓋充足（106.18%），計算。
# ✅2015 5  嘉義縣朴子市 覆蓋充足（93.78%），計算。
# ✅2015 5  嘉義縣東石鄉 覆蓋充足（100.02%），計算。
# ✅2015 5  嘉義縣梅山鄉 覆蓋充足（58.82%），計算。
# ✅2015 5  嘉義縣民雄鄉 覆蓋充足（96.59%），計算。
# ✅2015 5  嘉義縣水上鄉 覆蓋充足（83.60%），計算。
# ✅2015 5  嘉義縣溪口鄉 覆蓋充足（144.53%），計算。
# ✅2015 5  嘉義縣番路鄉 覆蓋充足（83.37%），計算。
# ✅2015 5  嘉義縣竹崎鄉 覆蓋充足（59.75%），計算。
# ✅2015 5  嘉義縣義竹鄉 覆蓋充足（133.76%），計算。
# ✅2015 5  嘉義縣鹿草鄉 覆蓋充足（128.87%），計算。
# ✅2015 5  基隆市七堵區 覆蓋充足（125.04%），計算。
# ✅2015 5  基隆市仁愛區 覆蓋充足（257.15%），計算。
# ✅2015 5  基隆市信義區 覆蓋充足（110.51%），計算。
# ✅2015 5  基隆市安樂區 覆蓋充足（126.24%），計算。
# ✅2015 5  基隆市暖暖區 覆蓋充足（102.34%），計算。
# ✅2015 5  宜蘭縣三星鄉 覆蓋充足（119.74%），計算。
# ✅2015 5  宜蘭縣五結鄉 覆蓋充足（116.30%），計算。
# ✅2015 5  宜蘭縣冬山鄉 覆蓋充足（124.73%），計算。
# ⚠️2015 5 宜蘭縣南澳鄉 覆蓋不足（37.81%），略過。
# ✅2015 5  宜蘭縣員山鄉 覆蓋充足（82.76%），計算。
# ✅2015 5  宜蘭縣壯圍鄉 覆蓋充足（89.08%），計算。
# ⚠️2015 5 宜蘭縣大同鄉 覆蓋不足（19.78%），略過。
# ✅2015 5  宜蘭縣宜蘭市 覆蓋充足（153.97%），計算。
# ✅2015 5  宜蘭縣礁溪鄉 覆蓋充足（93.07%），計算。
# ✅2015 5  宜蘭縣蘇澳鎮 覆蓋充足（130.78%），計算。
# ✅2015 5  宜蘭縣頭城鎮 覆蓋充足（80.00%），計算。
# ✅2015 5  屏東縣三地門鄉 覆蓋充足（81.91%），計算。
# ✅2015 5  屏東縣九如鄉 覆蓋充足（108.69%），計算。
# ✅2015 5  屏東縣佳冬鄉 覆蓋充足（108.71%），計算。
# ✅2015 5  屏東縣來義鄉 覆蓋充足（57.75%），計算。
# ✅2015 5  屏東縣內埔鄉 覆蓋充足（121.47%），計算。
# ✅2015 5  屏東縣南州鄉 覆蓋充足（62.32%），計算。
# ✅2015 5  屏東縣屏東市 覆蓋充足（124.15%），計算。
# ✅2015 5  屏東縣崁頂鄉 覆蓋充足（138.82%），計算。
# ✅2015 5  屏東縣恆春鎮 覆蓋充足（99.71%），計算。
# ✅2015 5  屏東縣新園鄉 覆蓋充足（77.39%），計算。
# ✅2015 5  屏東縣新埤鄉 覆蓋充足（144.47%），計算。
# ✅2015 5  屏東縣春日鄉 覆蓋充足（82.84%），計算。
# ✅2015 5  屏東縣東港鎮 覆蓋充足（114.01%），計算。
# ✅2015 5  屏東縣枋寮鄉 覆蓋充足（96.78%），計算。
# ✅2015 5  屏東縣枋山鄉 覆蓋充足（259.16%），計算。
# ✅2015 5  屏東縣林邊鄉 覆蓋充足（137.18%），計算。
# ⚠️2015 5 屏東縣泰武鄉 覆蓋不足（47.19%），略過。
# ✅2015 5  屏東縣滿州鄉 覆蓋充足（117.85%），計算。
# ✅2015 5  屏東縣潮州鎮 覆蓋充足（82.63%），計算。
# ✅2015 5  屏東縣牡丹鄉 覆蓋充足（107.42%），計算。
# ✅2015 5  屏東縣獅子鄉 覆蓋充足（85.98%），計算。
# ✅2015 5  屏東縣琉球鄉 覆蓋充足（170.86%），計算。
# ✅2015 5  屏東縣瑪家鄉 覆蓋充足（94.96%），計算。
# ✅2015 5  屏東縣竹田鄉 覆蓋充足（118.56%），計算。
# ✅2015 5  屏東縣萬丹鄉 覆蓋充足（118.56%），計算。
# ✅2015 5  屏東縣萬巒鄉 覆蓋充足（57.76%），計算。
# ✅2015 5  屏東縣車城鄉 覆蓋充足（117.82%），計算。
# ✅2015 5  屏東縣里港鄉 覆蓋充足（100.82%），計算。
# ✅2015 5  屏東縣長治鄉 覆蓋充足（51.16%），計算。
# ⚠️2015 5 屏東縣霧臺鄉 覆蓋不足（3.84%），略過。
# ✅2015 5  屏東縣高樹鄉 覆蓋充足（87.02%），計算。
# ✅2015 5  屏東縣鹽埔鄉 覆蓋充足（118.79%），計算。
# ✅2015 5  屏東縣麟洛鄉 覆蓋充足（168.51%），計算。
# ...
# ✅2015 49  雲林縣斗六市 覆蓋充足（127.62%），計算。
# ✅2015 49  雲林縣斗南鎮 覆蓋充足（121.28%），計算。
# ✅2015 49  雲林縣東勢鄉 覆蓋充足（126.06%），計算。
# ✅2015 49  雲林縣林內鄉 覆蓋充足（89.88%），計算。
# ✅2015 49  雲林縣水林鄉 覆蓋充足（128.70%），計算。
# ✅2015 49  雲林縣臺西鄉 覆蓋充足（101.19%），計算。
# ✅2015 49  雲林縣莿桐鄉 覆蓋充足（102.50%），計算。
# ✅2015 49  雲林縣虎尾鎮 覆蓋充足（119.96%），計算。
# ✅2015 49  雲林縣褒忠鄉 覆蓋充足（98.56%），計算。
# ✅2015 49  雲林縣西螺鎮 覆蓋充足（93.61%），計算。
# ✅2015 49  雲林縣麥寮鄉 覆蓋充足（112.12%），計算。
# ✅2015 49  高雄市三民區 覆蓋充足（69.01%），計算。
# ✅2015 49  高雄市仁武區 覆蓋充足（92.95%），計算。
# ✅2015 49  高雄市內門區 覆蓋充足（98.86%），計算。
# ✅2015 49  高雄市六龜區 覆蓋充足（84.46%），計算。
# ✅2015 49  高雄市前金區 覆蓋充足（596.19%），計算。
# ✅2015 49  高雄市前鎮區 覆蓋充足（165.67%），計算。
# ✅2015 49  高雄市大寮區 覆蓋充足（117.00%），計算。
# ✅2015 49  高雄市大樹區 覆蓋充足（121.51%），計算。
# ✅2015 49  高雄市大社區 覆蓋充足（92.44%），計算。
# ✅2015 49  高雄市小港區 覆蓋充足（108.63%），計算。
# ✅2015 49  高雄市岡山區 覆蓋充足（117.85%），計算。
# ✅2015 49  高雄市左營區 覆蓋充足（103.53%），計算。
# ✅2015 49  高雄市彌陀區 覆蓋充足（79.55%），計算。
# ✅2015 49  高雄市旗山區 覆蓋充足（136.24%），計算。
# ✅2015 49  高雄市旗津區 覆蓋充足（80.64%），計算。
# ✅2015 49  高雄市杉林區 覆蓋充足（112.98%），計算。
# ✅2015 49  高雄市林園區 覆蓋充足（98.20%），計算。
# ⚠️2015 49 高雄市桃源區 覆蓋不足（2.40%），略過。
# ✅2015 49  高雄市梓官區 覆蓋充足（98.91%），計算。
# ✅2015 49  高雄市楠梓區 覆蓋充足（165.36%），計算。
# ⚠️2015 49 高雄市橋頭區 覆蓋不足（48.07%），略過。
# ✅2015 49  高雄市永安區 覆蓋充足（131.11%），計算。
# ✅2015 49  高雄市湖內區 覆蓋充足（107.74%），計算。
# ✅2015 49  高雄市燕巢區 覆蓋充足（120.12%），計算。
# ✅2015 49  高雄市田寮區 覆蓋充足（103.84%），計算。
# ✅2015 49  高雄市甲仙區 覆蓋充足（66.19%），計算。
# ✅2015 49  高雄市美濃區 覆蓋充足（98.82%），計算。
# ✅2015 49  高雄市苓雅區 覆蓋充足（139.82%），計算。
# ⚠️2015 49 高雄市茂林區 覆蓋不足（9.70%），略過。
# ✅2015 49  高雄市茄萣區 覆蓋充足（68.70%），計算。
# ✅2015 49  高雄市路竹區 覆蓋充足（115.73%），計算。
# ✅2015 49  高雄市阿蓮區 覆蓋充足（67.10%），計算。
# ✅2015 49  高雄市鳥松區 覆蓋充足（142.28%），計算。
# ✅2015 49  高雄市鳳山區 覆蓋充足（83.99%），計算。
# ✅2015 49  高雄市鼓山區 覆蓋充足（158.89%），計算。
# ✅ 完成：NO 2015 week 49
# ✅2015 50  南投縣中寮鄉 覆蓋充足（97.70%），計算。
# ⚠️2015 50 南投縣仁愛鄉 覆蓋不足（5.76%），略過。
# ⚠️2015 50 南投縣信義鄉 覆蓋不足（1.65%），略過。
# ✅2015 50  南投縣南投市 覆蓋充足（114.11%），計算。
# ✅2015 50  南投縣名間鄉 覆蓋充足（118.21%），計算。
# ✅2015 50  南投縣國姓鄉 覆蓋充足（68.26%），計算。
# ✅2015 50  南投縣埔里鎮 覆蓋充足（95.67%），計算。
# ✅2015 50  南投縣水里鄉 覆蓋充足（62.89%），計算。
# ✅2015 50  南投縣竹山鎮 覆蓋充足（63.42%），計算。
# ✅2015 50  南投縣草屯鎮 覆蓋充足（90.14%），計算。
# ✅2015 50  南投縣集集鎮 覆蓋充足（88.45%），計算。
# ✅2015 50  南投縣魚池鄉 覆蓋充足（65.93%），計算。
# ✅2015 50  南投縣鹿谷鄉 覆蓋充足（81.95%），計算。
# ✅2015 50  嘉義市東區 覆蓋充足（78.49%），計算。
# ✅2015 50  嘉義市西區 覆蓋充足（156.84%），計算。
# ✅2015 50  嘉義縣中埔鄉 覆蓋充足（90.00%），計算。
# ✅2015 50  嘉義縣六腳鄉 覆蓋充足（112.78%），計算。
# ✅2015 50  嘉義縣大埔鄉 覆蓋充足（100.81%），計算。
# ✅2015 50  嘉義縣大林鎮 覆蓋充足（108.78%），計算。
# ✅2015 50  嘉義縣太保市 覆蓋充足（123.39%），計算。
# ✅2015 50  嘉義縣布袋鎮 覆蓋充足（88.91%），計算。
# ✅2015 50  嘉義縣新港鄉 覆蓋充足（106.18%），計算。
# ✅2015 50  嘉義縣朴子市 覆蓋充足（93.78%），計算。
# ✅2015 50  嘉義縣東石鄉 覆蓋充足（100.02%），計算。
# ✅2015 50  嘉義縣梅山鄉 覆蓋充足（58.82%），計算。
# ✅2015 50  嘉義縣民雄鄉 覆蓋充足（96.59%），計算。
# ✅2015 50  嘉義縣水上鄉 覆蓋充足（83.60%），計算。
# ✅2015 50  嘉義縣溪口鄉 覆蓋充足（144.53%），計算。
# ✅2015 50  嘉義縣番路鄉 覆蓋充足（83.37%），計算。
# ✅2015 50  嘉義縣竹崎鄉 覆蓋充足（59.75%），計算。
# ✅2015 50  嘉義縣義竹鄉 覆蓋充足（133.76%），計算。
# ✅2015 50  嘉義縣鹿草鄉 覆蓋充足（128.87%），計算。
# ✅2015 50  基隆市七堵區 覆蓋充足（125.04%），計算。
# ✅2015 50  基隆市仁愛區 覆蓋充足（257.15%），計算。
# ✅2015 50  基隆市信義區 覆蓋充足（110.51%），計算。
# ✅2015 50  基隆市安樂區 覆蓋充足（126.24%），計算。
# ✅2015 50  基隆市暖暖區 覆蓋充足（102.34%），計算。
# ✅2015 50  宜蘭縣三星鄉 覆蓋充足（119.74%），計算。
# ✅2015 50  宜蘭縣五結鄉 覆蓋充足（116.30%），計算。
# ✅2015 50  宜蘭縣冬山鄉 覆蓋充足（124.73%），計算。
# ⚠️2015 50 宜蘭縣南澳鄉 覆蓋不足（37.81%），略過。
# ✅2015 50  宜蘭縣員山鄉 覆蓋充足（82.76%），計算。
# ✅2015 50  宜蘭縣壯圍鄉 覆蓋充足（89.08%），計算。
# ⚠️2015 50 宜蘭縣大同鄉 覆蓋不足（19.78%），略過。
# ✅2015 50  宜蘭縣宜蘭市 覆蓋充足（153.97%），計算。
# ✅2015 50  宜蘭縣礁溪鄉 覆蓋充足（93.07%），計算。
# ✅2015 50  宜蘭縣蘇澳鎮 覆蓋充足（130.78%），計算。
# ✅2015 50  宜蘭縣頭城鎮 覆蓋充足（80.00%），計算。
# ✅2015 50  屏東縣三地門鄉 覆蓋充足（81.91%），計算。
# ✅2015 50  屏東縣九如鄉 覆蓋充足（108.69%），計算。
# ✅2015 50  屏東縣佳冬鄉 覆蓋充足（108.71%），計算。
# ✅2015 50  屏東縣來義鄉 覆蓋充足（57.75%），計算。
# ✅2015 50  屏東縣內埔鄉 覆蓋充足（121.47%），計算。
# ✅2015 50  屏東縣南州鄉 覆蓋充足（62.32%），計算。
# ✅2015 50  屏東縣屏東市 覆蓋充足（124.15%），計算。
# ✅2015 50  屏東縣崁頂鄉 覆蓋充足（138.82%），計算。
# ✅2015 50  屏東縣恆春鎮 覆蓋充足（99.71%），計算。
# ✅2015 50  屏東縣新園鄉 覆蓋充足（77.39%），計算。
# ✅2015 50  屏東縣新埤鄉 覆蓋充足（144.47%），計算。
# ✅2015 50  屏東縣春日鄉 覆蓋充足（82.84%），計算。
# ✅2015 50  屏東縣東港鎮 覆蓋充足（114.01%），計算。
# ✅2015 50  屏東縣枋寮鄉 覆蓋充足（96.78%），計算。
# ✅2015 50  屏東縣枋山鄉 覆蓋充足（259.16%），計算。
# ✅2015 50  屏東縣林邊鄉 覆蓋充足（137.18%），計算。
# ⚠️2015 50 屏東縣泰武鄉 覆蓋不足（47.19%），略過。
# ✅2015 50  屏東縣滿州鄉 覆蓋充足（117.85%），計算。
# ✅2015 50  屏東縣潮州鎮 覆蓋充足（82.63%），計算。
# ✅2015 50  屏東縣牡丹鄉 覆蓋充足（107.42%），計算。
# ✅2015 50  屏東縣獅子鄉 覆蓋充足（85.98%），計算。
# ✅2015 50  屏東縣琉球鄉 覆蓋充足（170.86%），計算。
# ✅2015 50  屏東縣瑪家鄉 覆蓋充足（94.96%），計算。
# ✅2015 50  屏東縣竹田鄉 覆蓋充足（118.56%），計算。
# ✅2015 50  屏東縣萬丹鄉 覆蓋充足（118.56%），計算。
# ✅2015 50  屏東縣萬巒鄉 覆蓋充足（57.76%），計算。
# ✅2015 50  屏東縣車城鄉 覆蓋充足（117.82%），計算。
# ✅2015 50  屏東縣里港鄉 覆蓋充足（100.82%），計算。
# ✅2015 50  屏東縣長治鄉 覆蓋充足（51.16%），計算。
# ⚠️2015 50 屏東縣霧臺鄉 覆蓋不足（3.84%），略過。
# ✅2015 50  屏東縣高樹鄉 覆蓋充足（87.02%），計算。
# ✅2015 50  屏東縣鹽埔鄉 覆蓋充足（118.79%），計算。
# ✅2015 50  屏東縣麟洛鄉 覆蓋充足（168.51%），計算。
# ✅2015 50  彰化縣二林鎮 覆蓋充足（101.64%），計算。
# ✅2015 50  彰化縣二水鄉 覆蓋充足（131.73%），計算。
# ✅2015 50  彰化縣伸港鄉 覆蓋充足（99.57%），計算。
# ✅2015 50  彰化縣北斗鎮 覆蓋充足（118.61%），計算。
# ✅2015 50  彰化縣和美鎮 覆蓋充足（122.71%），計算。
# ✅2015 50  彰化縣員林市 覆蓋充足（59.44%），計算。
# ✅2015 50  彰化縣埔心鄉 覆蓋充足（55.82%），計算。
# ✅2015 50  彰化縣埔鹽鄉 覆蓋充足（119.96%），計算。
# ✅2015 50  彰化縣埤頭鄉 覆蓋充足（137.86%），計算。
# ✅2015 50  彰化縣大城鄉 覆蓋充足（110.56%），計算。
# ✅2015 50  彰化縣大村鄉 覆蓋充足（153.86%），計算。
# ✅2015 50  彰化縣彰化市 覆蓋充足（71.25%），計算。
# ✅2015 50  彰化縣永靖鄉 覆蓋充足（115.44%），計算。
# ✅2015 50  彰化縣溪州鄉 覆蓋充足（118.39%），計算。
# ✅2015 50  彰化縣溪湖鎮 覆蓋充足（150.99%），計算。
# ✅2015 50  彰化縣田中鎮 覆蓋充足（68.00%），計算。
# ✅2015 50  彰化縣田尾鄉 覆蓋充足（94.82%），計算。
# ✅2015 50  彰化縣社頭鄉 覆蓋充足（130.46%），計算。
# ✅2015 50  彰化縣福興鄉 覆蓋充足（161.04%），計算。
# ✅2015 50  彰化縣秀水鄉 覆蓋充足（80.55%），計算。
# ✅2015 50  彰化縣竹塘鄉 覆蓋充足（111.85%），計算。
# ✅2015 50  彰化縣線西鄉 覆蓋充足（113.73%），計算。
# ✅2015 50  彰化縣芬園鄉 覆蓋充足（152.98%），計算。
# ✅2015 50  彰化縣花壇鄉 覆蓋充足（130.30%），計算。
# ✅2015 50  彰化縣芳苑鄉 覆蓋充足（104.76%），計算。
# ✅2015 50  彰化縣鹿港鎮 覆蓋充足（84.69%），計算。
# ✅2015 50  新北市三峽區 覆蓋充足（86.50%），計算。
# ✅2015 50  新北市三芝區 覆蓋充足（86.75%），計算。
# ✅2015 50  新北市三重區 覆蓋充足（65.14%），計算。
# ✅2015 50  新北市中和區 覆蓋充足（120.58%），計算。
# ✅2015 50  新北市五股區 覆蓋充足（102.37%），計算。
# ✅2015 50  新北市八里區 覆蓋充足（117.87%），計算。
# ✅2015 50  新北市土城區 覆蓋充足（117.38%），計算。
# ✅2015 50  新北市坪林區 覆蓋充足（69.61%），計算。
# ✅2015 50  新北市平溪區 覆蓋充足（131.69%），計算。
# ✅2015 50  新北市新店區 覆蓋充足（96.68%），計算。
# ✅2015 50  新北市新莊區 覆蓋充足（169.91%），計算。
# ✅2015 50  新北市板橋區 覆蓋充足（110.09%），計算。
# ✅2015 50  新北市林口區 覆蓋充足（129.46%），計算。
# ✅2015 50  新北市樹林區 覆蓋充足（110.11%），計算。
# ✅2015 50  新北市永和區 覆蓋充足（190.21%），計算。
# ✅2015 50  新北市汐止區 覆蓋充足（114.21%），計算。
# ✅2015 50  新北市淡水區 覆蓋充足（96.16%），計算。
# ✅2015 50  新北市深坑區 覆蓋充足（111.86%），計算。
# ⚠️2015 50 新北市烏來區 覆蓋不足（31.61%），略過。
# ✅2015 50  新北市瑞芳區 覆蓋充足（97.31%），計算。
# ✅2015 50  新北市石碇區 覆蓋充足（107.30%），計算。
# ✅2015 50  新北市石門區 覆蓋充足（110.52%），計算。
# ✅2015 50  新北市萬里區 覆蓋充足（110.56%），計算。
# ✅2015 50  新北市蘆洲區 覆蓋充足（151.81%），計算。
# ✅2015 50  新北市貢寮區 覆蓋充足（115.08%），計算。
# ✅2015 50  新北市金山區 覆蓋充足（98.16%），計算。
# ✅2015 50  新北市雙溪區 覆蓋充足（104.53%），計算。
# ✅2015 50  新北市鶯歌區 覆蓋充足（107.27%），計算。
# ✅2015 50  新竹市北區 覆蓋充足（99.36%），計算。
# ✅2015 50  新竹市東區 覆蓋充足（68.33%），計算。
# ✅2015 50  新竹市香山區 覆蓋充足（87.97%），計算。
# ⚠️2015 50 新竹縣五峰鄉 覆蓋不足（22.31%），略過。
# ✅2015 50  新竹縣北埔鄉 覆蓋充足（87.72%），計算。
# ✅2015 50  新竹縣寶山鄉 覆蓋充足（109.37%），計算。
# ⚠️2015 50 新竹縣尖石鄉 覆蓋不足（11.20%），略過。
# ✅2015 50  新竹縣峨眉鄉 覆蓋充足（125.87%），計算。
# ✅2015 50  新竹縣新埔鎮 覆蓋充足（97.34%），計算。
# ✅2015 50  新竹縣新豐鄉 覆蓋充足（117.40%），計算。
# ✅2015 50  新竹縣橫山鄉 覆蓋充足（107.90%），計算。
# ✅2015 50  新竹縣湖口鄉 覆蓋充足（80.74%），計算。
# ✅2015 50  新竹縣竹北市 覆蓋充足（116.31%），計算。
# ✅2015 50  新竹縣竹東鎮 覆蓋充足（131.36%），計算。
# ✅2015 50  新竹縣芎林鄉 覆蓋充足（117.35%），計算。
# ✅2015 50  新竹縣關西鎮 覆蓋充足（121.63%），計算。
# ✅2015 50  桃園市中壢區 覆蓋充足（92.35%），計算。
# ✅2015 50  桃園市八德區 覆蓋充足（69.32%），計算。
# ✅2015 50  桃園市大園區 覆蓋充足（104.01%），計算。
# ✅2015 50  桃園市大溪區 覆蓋充足（122.59%），計算。
# ✅2015 50  桃園市平鎮區 覆蓋充足（134.78%），計算。
# ⚠️2015 50 桃園市復興區 覆蓋不足（24.34%），略過。
# ✅2015 50  桃園市新屋區 覆蓋充足（91.84%），計算。
# ✅2015 50  桃園市桃園區 覆蓋充足（136.31%），計算。
# ✅2015 50  桃園市楊梅區 覆蓋充足（117.57%），計算。
# ✅2015 50  桃園市蘆竹區 覆蓋充足（109.58%），計算。
# ✅2015 50  桃園市觀音區 覆蓋充足（121.68%），計算。
# ✅2015 50  桃園市龍潭區 覆蓋充足（123.40%），計算。
# ✅2015 50  桃園市龜山區 覆蓋充足（81.98%），計算。
# ✅2015 50  臺中市北屯區 覆蓋充足（113.97%），計算。
# ✅2015 50  臺中市南屯區 覆蓋充足（115.59%），計算。
# ✅2015 50  臺中市后里區 覆蓋充足（122.88%），計算。
# ✅2015 50  臺中市外埔區 覆蓋充足（139.16%），計算。
# ✅2015 50  臺中市大安區 覆蓋充足（98.92%），計算。
# ✅2015 50  臺中市大甲區 覆蓋充足（98.68%），計算。
# ✅2015 50  臺中市大肚區 覆蓋充足（122.40%），計算。
# ✅2015 50  臺中市大里區 覆蓋充足（201.60%），計算。
# ✅2015 50  臺中市大雅區 覆蓋充足（142.76%），計算。
# ✅2015 50  臺中市太平區 覆蓋充足（77.74%），計算。
# ✅2015 50  臺中市新社區 覆蓋充足（71.36%），計算。
# ✅2015 50  臺中市東勢區 覆蓋充足（76.07%），計算。
# ✅2015 50  臺中市東區 覆蓋充足（173.74%），計算。
# ✅2015 50  臺中市梧棲區 覆蓋充足（106.42%），計算。
# ✅2015 50  臺中市沙鹿區 覆蓋充足（116.50%），計算。
# ✅2015 50  臺中市清水區 覆蓋充足（131.26%），計算。
# ✅2015 50  臺中市潭子區 覆蓋充足（90.67%），計算。
# ✅2015 50  臺中市烏日區 覆蓋充足（83.07%），計算。
# ✅2015 50  臺中市石岡區 覆蓋充足（65.77%），計算。
# ✅2015 50  臺中市神岡區 覆蓋充足（96.44%），計算。
# ✅2015 50  臺中市西區 覆蓋充足（184.52%），計算。
# ✅2015 50  臺中市西屯區 覆蓋充足（117.31%），計算。
# ✅2015 50  臺中市豐原區 覆蓋充足（112.61%），計算。
# ✅2015 50  臺中市霧峰區 覆蓋充足（97.40%），計算。
# ✅2015 50  臺中市龍井區 覆蓋充足（90.10%），計算。
# ✅2015 50  臺北市中山區 覆蓋充足（83.44%），計算。
# ✅2015 50  臺北市中正區 覆蓋充足（157.67%），計算。
# ✅2015 50  臺北市信義區 覆蓋充足（104.09%），計算。
# ✅2015 50  臺北市內湖區 覆蓋充足（73.33%），計算。
# ✅2015 50  臺北市北投區 覆蓋充足（121.74%），計算。
# ✅2015 50  臺北市南港區 覆蓋充足（106.73%），計算。
# ✅2015 50  臺北市士林區 覆蓋充足（113.33%），計算。
# ✅2015 50  臺北市文山區 覆蓋充足（149.95%），計算。
# ✅2015 50  臺北市松山區 覆蓋充足（135.30%），計算。
# ✅2015 50  臺北市萬華區 覆蓋充足（156.89%），計算。
# ✅2015 50  臺南市七股區 覆蓋充足（115.03%），計算。
# ✅2015 50  臺南市下營區 覆蓋充足（104.82%），計算。
# ✅2015 50  臺南市中西區 覆蓋充足（183.81%），計算。
# ✅2015 50  臺南市仁德區 覆蓋充足（139.38%），計算。
# ✅2015 50  臺南市佳里區 覆蓋充足（119.79%），計算。
# ✅2015 50  臺南市六甲區 覆蓋充足（87.67%），計算。
# ✅2015 50  臺南市北區 覆蓋充足（119.11%），計算。
# ✅2015 50  臺南市北門區 覆蓋充足（71.88%），計算。
# ✅2015 50  臺南市南化區 覆蓋充足（102.52%），計算。
# ✅2015 50  臺南市南區 覆蓋充足（83.80%），計算。
# ✅2015 50  臺南市善化區 覆蓋充足（131.49%），計算。
# ✅2015 50  臺南市大內區 覆蓋充足（98.88%），計算。
# ✅2015 50  臺南市學甲區 覆蓋充足（128.97%），計算。
# ✅2015 50  臺南市安南區 覆蓋充足（100.09%），計算。
# ✅2015 50  臺南市安定區 覆蓋充足（110.29%），計算。
# ✅2015 50  臺南市官田區 覆蓋充足（129.65%），計算。
# ✅2015 50  臺南市將軍區 覆蓋充足（122.57%），計算。
# ✅2015 50  臺南市山上區 覆蓋充足（84.78%），計算。
# ✅2015 50  臺南市左鎮區 覆蓋充足（112.64%），計算。
# ✅2015 50  臺南市後壁區 覆蓋充足（113.24%），計算。
# ✅2015 50  臺南市新化區 覆蓋充足（75.64%），計算。
# ✅2015 50  臺南市新市區 覆蓋充足（139.36%），計算。
# ✅2015 50  臺南市新營區 覆蓋充足（91.03%），計算。
# ✅2015 50  臺南市東區 覆蓋充足（90.83%），計算。
# ✅2015 50  臺南市東山區 覆蓋充足（94.44%），計算。
# ✅2015 50  臺南市柳營區 覆蓋充足（133.06%），計算。
# ✅2015 50  臺南市楠西區 覆蓋充足（118.20%），計算。
# ✅2015 50  臺南市歸仁區 覆蓋充足（106.58%），計算。
# ✅2015 50  臺南市永康區 覆蓋充足（114.73%），計算。
# ✅2015 50  臺南市玉井區 覆蓋充足（109.34%），計算。
# ✅2015 50  臺南市白河區 覆蓋充足（118.75%），計算。
# ✅2015 50  臺南市西港區 覆蓋充足（69.87%），計算。
# ✅2015 50  臺南市關廟區 覆蓋充足（109.40%），計算。
# ✅2015 50  臺南市鹽水區 覆蓋充足（113.55%），計算。
# ✅2015 50  臺南市麻豆區 覆蓋充足（85.36%），計算。
# ✅2015 50  臺南市龍崎區 覆蓋充足（112.77%），計算。
# ✅2015 50  臺東縣卑南鄉 覆蓋充足（60.54%），計算。
# ✅2015 50  臺東縣大武鄉 覆蓋充足（92.74%），計算。
# ✅2015 50  臺東縣太麻里鄉 覆蓋充足（90.54%），計算。
# ⚠️2015 50 臺東縣延平鄉 覆蓋不足（17.06%），略過。
# ✅2015 50  臺東縣成功鎮 覆蓋充足（80.06%），計算。
# ✅2015 50  臺東縣東河鄉 覆蓋充足（92.00%），計算。
# ✅2015 50  臺東縣池上鄉 覆蓋充足（103.50%），計算。
# ⚠️2015 50 臺東縣海端鄉 覆蓋不足（7.87%），略過。
# ✅2015 50  臺東縣綠島鄉 覆蓋充足（164.40%），計算。
# ✅2015 50  臺東縣臺東市 覆蓋充足（114.02%），計算。
# ✅2015 50  臺東縣蘭嶼鄉 覆蓋充足（123.88%），計算。
# ✅2015 50  臺東縣達仁鄉 覆蓋充足（72.97%），計算。
# ⚠️2015 50 臺東縣金峰鄉 覆蓋不足（33.25%），略過。
# ✅2015 50  臺東縣長濱鄉 覆蓋充足（93.05%），計算。
# ✅2015 50  臺東縣關山鎮 覆蓋充足（97.07%），計算。
# ✅2015 50  臺東縣鹿野鄉 覆蓋充足（88.13%），計算。
# ✅2015 50  花蓮縣光復鄉 覆蓋充足（105.96%），計算。
# ⚠️2015 50 花蓮縣卓溪鄉 覆蓋不足（14.57%），略過。
# ✅2015 50  花蓮縣吉安鄉 覆蓋充足（130.35%），計算。
# ✅2015 50  花蓮縣壽豐鄉 覆蓋充足（101.75%），計算。
# ✅2015 50  花蓮縣富里鄉 覆蓋充足（81.76%），計算。
# ✅2015 50  花蓮縣新城鄉 覆蓋充足（80.40%），計算。
# ✅2015 50  花蓮縣玉里鎮 覆蓋充足（122.08%），計算。
# ✅2015 50  花蓮縣瑞穗鄉 覆蓋充足（98.56%），計算。
# ⚠️2015 50 花蓮縣秀林鄉 覆蓋不足（18.78%），略過。
# ⚠️2015 50 花蓮縣花蓮市 覆蓋不足（37.85%），略過。
# ⚠️2015 50 花蓮縣萬榮鄉 覆蓋不足（17.77%），略過。
# ✅2015 50  花蓮縣豐濱鄉 覆蓋充足（124.71%），計算。
# ✅2015 50  花蓮縣鳳林鎮 覆蓋充足（98.30%），計算。
# ✅2015 50  苗栗縣三灣鄉 覆蓋充足（86.45%），計算。
# ✅2015 50  苗栗縣三義鄉 覆蓋充足（103.79%），計算。
# ✅2015 50  苗栗縣公館鄉 覆蓋充足（114.38%），計算。
# ✅2015 50  苗栗縣卓蘭鎮 覆蓋充足（75.66%），計算。
# ✅2015 50  苗栗縣南庄鄉 覆蓋充足（57.84%），計算。
# ⚠️2015 50 苗栗縣大湖鄉 覆蓋不足（38.64%），略過。
# ✅2015 50  苗栗縣後龍鎮 覆蓋充足（122.28%），計算。
# ⚠️2015 50 苗栗縣泰安鄉 覆蓋不足（1.94%），略過。
# ✅2015 50  苗栗縣獅潭鄉 覆蓋充足（103.29%），計算。
# ✅2015 50  苗栗縣竹南鎮 覆蓋充足（112.57%），計算。
# ✅2015 50  苗栗縣苑裡鎮 覆蓋充足（84.18%），計算。
# ✅2015 50  苗栗縣苗栗市 覆蓋充足（93.33%），計算。
# ✅2015 50  苗栗縣西湖鄉 覆蓋充足（114.46%），計算。
# ✅2015 50  苗栗縣通霄鎮 覆蓋充足（113.23%），計算。
# ✅2015 50  苗栗縣造橋鄉 覆蓋充足（121.21%），計算。
# ✅2015 50  苗栗縣銅鑼鄉 覆蓋充足（120.05%），計算。
# ✅2015 50  苗栗縣頭份市 覆蓋充足（154.94%），計算。
# ✅2015 50  苗栗縣頭屋鄉 覆蓋充足（90.85%），計算。
# ✅2015 50  雲林縣二崙鄉 覆蓋充足（96.36%），計算。
# ✅2015 50  雲林縣元長鄉 覆蓋充足（81.16%），計算。
# ✅2015 50  雲林縣北港鎮 覆蓋充足（84.40%），計算。
# ✅2015 50  雲林縣口湖鄉 覆蓋充足（106.49%），計算。
# ✅2015 50  雲林縣古坑鄉 覆蓋充足（91.63%），計算。
# ✅2015 50  雲林縣四湖鄉 覆蓋充足（113.61%），計算。
# ✅2015 50  雲林縣土庫鎮 覆蓋充足（121.79%），計算。
# ✅2015 50  雲林縣大埤鄉 覆蓋充足（79.32%），計算。
# ✅2015 50  雲林縣崙背鄉 覆蓋充足（61.51%），計算。
# ✅2015 50  雲林縣斗六市 覆蓋充足（127.62%），計算。
# ✅2015 50  雲林縣斗南鎮 覆蓋充足（121.28%），計算。
# ✅2015 50  雲林縣東勢鄉 覆蓋充足（126.06%），計算。
# ✅2015 50  雲林縣林內鄉 覆蓋充足（89.88%），計算。
# ✅2015 50  雲林縣水林鄉 覆蓋充足（128.70%），計算。
# ✅2015 50  雲林縣臺西鄉 覆蓋充足（101.19%），計算。
# ✅2015 50  雲林縣莿桐鄉 覆蓋充足（102.50%），計算。
# ✅2015 50  雲林縣虎尾鎮 覆蓋充足（119.96%），計算。
# ✅2015 50  雲林縣褒忠鄉 覆蓋充足（98.56%），計算。
# ✅2015 50  雲林縣西螺鎮 覆蓋充足（93.61%），計算。
# ✅2015 50  雲林縣麥寮鄉 覆蓋充足（112.12%），計算。
# ✅2015 50  高雄市三民區 覆蓋充足（69.01%），計算。
# ✅2015 50  高雄市仁武區 覆蓋充足（92.95%），計算。
# ✅2015 50  高雄市內門區 覆蓋充足（98.86%），計算。
# ✅2015 50  高雄市六龜區 覆蓋充足（84.46%），計算。
# ✅2015 50  高雄市前金區 覆蓋充足（596.19%），計算。
# ✅2015 50  高雄市前鎮區 覆蓋充足（165.67%），計算。
# ✅2015 50  高雄市大寮區 覆蓋充足（117.00%），計算。
# ✅2015 50  高雄市大樹區 覆蓋充足（121.51%），計算。
# ✅2015 50  高雄市大社區 覆蓋充足（92.44%），計算。
# ✅2015 50  高雄市小港區 覆蓋充足（108.63%），計算。
# ✅2015 50  高雄市岡山區 覆蓋充足（117.85%），計算。
# ✅2015 50  高雄市左營區 覆蓋充足（103.53%），計算。
# ✅2015 50  高雄市彌陀區 覆蓋充足（79.55%），計算。
# ✅2015 50  高雄市旗山區 覆蓋充足（136.24%），計算。
# ✅2015 50  高雄市旗津區 覆蓋充足（80.64%），計算。
# ✅2015 50  高雄市杉林區 覆蓋充足（112.98%），計算。
# ✅2015 50  高雄市林園區 覆蓋充足（98.20%），計算。
# ⚠️2015 50 高雄市桃源區 覆蓋不足（2.40%），略過。
# ✅2015 50  高雄市梓官區 覆蓋充足（98.91%），計算。
# ✅2015 50  高雄市楠梓區 覆蓋充足（165.36%），計算。
# ⚠️2015 50 高雄市橋頭區 覆蓋不足（48.07%），略過。
# ✅2015 50  高雄市永安區 覆蓋充足（131.11%），計算。
# ✅2015 50  高雄市湖內區 覆蓋充足（107.74%），計算。
# ✅2015 50  高雄市燕巢區 覆蓋充足（120.12%），計算。
# ✅2015 50  高雄市田寮區 覆蓋充足（103.84%），計算。
# ✅2015 50  高雄市甲仙區 覆蓋充足（66.19%），計算。
# ✅2015 50  高雄市美濃區 覆蓋充足（98.82%），計算。
# ✅2015 50  高雄市苓雅區 覆蓋充足（139.82%），計算。
# ⚠️2015 50 高雄市茂林區 覆蓋不足（9.70%），略過。
# ✅2015 50  高雄市茄萣區 覆蓋充足（68.70%），計算。
# ✅2015 50  高雄市路竹區 覆蓋充足（115.73%），計算。
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 43
#      40 town_poly = taiwan_map.loc[taiwan_map["town"] == town, "geometry"].values[0]
#      42 # 計算鄉鎮面積（使用 EPSG:3826 比較準）
# ---> 43 town_area = gpd.GeoSeries([town_poly], crs="EPSG:4326").to_crs(epsg=3826).area.values[0]
#      45 # 該鄉鎮內格點代表的覆蓋面積
#      46 # 每個格點代表的面積（以經緯度間隔近似）
#      47 grid_area = (iInterval * jInterval) * (111000 ** 2)  # 約略換算平方公尺
#
# File c:\Users\User\anaconda3\Lib\site-packages\geopandas\geoseries.py:1251, in GeoSeries.to_crs(self, crs, epsg)
#    1174 def to_crs(self, crs: Any | None = None, epsg: int | None = None) -> GeoSeries:
#    1175     """Return a ``GeoSeries`` with all geometries transformed to a new
#    1176     coordinate reference system.
#    1177
#    (...)
#    1248
#    1249     """
#    1250     return GeoSeries(
# -> 1251         self.values.to_crs(crs=crs, epsg=epsg), index=self.index, name=self.name
#    1252     )
#
# File c:\Users\User\anaconda3\Lib\site-packages\geopandas\_compat.py:85, in requires_pyproj.<locals>.wrapper(*args, **kwargs)
#      79 if not HAS_PYPROJ:
#      80     raise ImportError(
#      81         f"The 'pyproj' package is required for {func.__name__} to work. "
#      82         "Install it and initialize the object with a CRS before using it."
#      83         f"\nImporting pyproj resulted in: {pyproj_import_error}"
#      84     )
# ---> 85 return func(*args, **kwargs)
#
# File c:\Users\User\anaconda3\Lib\site-packages\geopandas\array.py:1116, in GeometryArray.to_crs(self, crs, epsg)
#    1112     return self
#    1114 transformer = TransformerFromCRS(self.crs, crs, always_xy=True)
# -> 1116 new_data = transform(self._data, transformer.transform)
#    1117 return GeometryArray(new_data, crs=crs)
#
# File c:\Users\User\anaconda3\Lib\site-packages\geopandas\array.py:1865, in transform(data, func)
#    1862 result = np.empty_like(data)
#    1864 coords = shapely.get_coordinates(data[~has_z], include_z=False)
# -> 1865 new_coords_z = func(coords[:, 0], coords[:, 1])
#    1866 result[~has_z] = shapely.set_coordinates(
#    1867     data[~has_z].copy(), np.array(new_coords_z).T
#    1868 )
#    1870 coords_z = shapely.get_coordinates(data[has_z], include_z=True)
#
# File c:\Users\User\anaconda3\Lib\site-packages\pyproj\transformer.py:839, in Transformer.transform(self, xx, yy, zz, tt, radians, errcheck, direction, inplace)
#     837     intime = None
#     838 # call pj_transform.  inx,iny,inz buffers modified in place.
# --> 839 self._transformer._transform(
#     840     inx=inx,
#     841     iny=iny,
#     842     inz=inz,
#     843     intime=intime,
#     844     direction=direction,
#     845     radians=radians,
#     846     errcheck=errcheck,
#     847 )
#     848 # if inputs were lists, tuples or floats, convert back.
#     849 outx = _convertback(x_data_type, inx)
#
# KeyboardInterrupt:

# %%
# === 6️⃣ 組裝整合表 ===
records = []
for (town, year, week), values in all_results.items():
    record = {"town": town, "year": year, "week": week}
    for factor in factors:
        record[factor] = values.get(factor, None)
    records.append(record)

result_df = pd.DataFrame(records)

# === 7️⃣ 合併ID對照 ===
result_df = result_df.merge(id_map, on="town", how="left")

# 將 ID 欄位移到第一欄
cols = ["ID"] + [c for c in result_df.columns if c != "ID"]
result_df = result_df[cols]

# 警告：有未對應的鄉鎮
missing_ids = result_df[result_df["ID"].isna()]["town"].unique()
if len(missing_ids) > 0:
    print("⚠️ 下列鄉鎮無法在 ID_CNAME.csv 中找到對應：")
    for name in missing_ids:
        print("  -", name)

# === 8️⃣ 輸出結果 ===
output_folder = "./6_exposure_by_town"
os.makedirs(output_folder, exist_ok=True)

result_df = result_df.sort_values(by=["ID", "year", "week"])
result_df.to_csv(f"{output_folder}/factors_weekly_exposure_with_ID.csv", index=False, encoding="utf-8-sig")

print("✅ 最終輸出完成：6_exposure_by_town/factors_weekly_exposure_with_ID.csv")
